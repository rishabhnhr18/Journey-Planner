# %% [markdown]
# # Saudi Master Data Generator — Self-contained Notebook
#
# This notebook implements the uploaded Saudi master-data generation specification. It creates these DataFrames:
#
# - `territory_df`
# - `salesperson_df`
# - `van_df`
# - `customer_df`
# - `holiday_df`
# - `config_df`
# - `rfm_scores_df`
#
# It also validates foreign keys and business rules, then writes CSV outputs plus `data_quality_report.json`.

# %%
# !pip install pandas folium

# %%
# !python -m pip install ortools

# %%
print("HEllo")
# Out:
# HEllo

# %%
# Self-contained Saudi master/reference data generator
# Run this notebook top-to-bottom. It writes outputs into ./saudi_master_data_output

import sys
import subprocess
import importlib.util
from pathlib import Path
from datetime import date, datetime, timedelta
import json
import math
import random
import string


def ensure_package(package_name, import_name=None):
    """Install package if missing. Safe for local/Jupyter execution."""
    import_name = import_name or package_name
    if importlib.util.find_spec(import_name) is None:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])

ensure_package("pandas")
ensure_package("numpy")
ensure_package("faker")

import numpy as np
import pandas as pd
from faker import Faker

try:
    fake = Faker(["ar_SA", "en_US"])
except Exception:
    fake = Faker("en_US")

# -----------------------------
# Static specification inputs
# -----------------------------

TERRITORIES = [
    {
        "territory_id": "TER_RUH",
        "territory_name": "Riyadh Central",
        "center_lat": 24.7136,
        "center_lng": 46.6753,
        "radius_km": 25,
        "warehouse_lat": 24.5790,
        "warehouse_lng": 46.8237,
        "warehouse_address": "Industrial Area, Riyadh",
    },
    {
        "territory_id": "TER_JED",
        "territory_name": "Jeddah North",
        "center_lat": 21.5433,
        "center_lng": 39.1728,
        "radius_km": 22,
        "warehouse_lat": 21.3429,
        "warehouse_lng": 39.2357,
        "warehouse_address": "Al Khomrah Logistics Area, Jeddah",
    },
    {
        "territory_id": "TER_DMM",
        "territory_name": "Dammam Metro",
        "center_lat": 26.4207,
        "center_lng": 50.0888,
        "radius_km": 20,
        "warehouse_lat": 26.2926,
        "warehouse_lng": 50.1629,
        "warehouse_address": "2nd Industrial City, Dammam",
    },
]

LOCALITIES = {
    "TER_RUH": [
        ("Olaya", 24.7115, 46.6746),
        ("Al Malaz", 24.6676, 46.7351),
        ("Al Sulaymaniyah", 24.7012, 46.7112),
        ("Al Yasmin", 24.8271, 46.6302),
        ("Hittin", 24.7636, 46.6022),
    ],
    "TER_JED": [
        ("Al Rawdah", 21.5656, 39.1652),
        ("Al Hamra", 21.5262, 39.1611),
        ("Al Safa", 21.5854, 39.2181),
        ("Al Salamah", 21.5948, 39.1485),
        ("Al Zahra", 21.6152, 39.1335),
    ],
    "TER_DMM": [
        ("Al Faisaliyah", 26.4282, 50.0786),
        ("Al Shati", 26.4701, 50.1124),
        ("Al Mazruiyah", 26.4481, 50.0962),
        ("Al Badiyah", 26.4021, 50.0587),
        ("Al Nuzha", 26.4337, 50.0433),
    ],
}

CITY_CODES = {"TER_RUH": "RUH", "TER_JED": "JED", "TER_DMM": "DMM"}
PLATE_PREFIXES = {"TER_RUH": "RU", "TER_JED": "JE", "TER_DMM": "DM"}

SAUDI_SALESPERSON_NAMES = [
    "Abdullah Al-Qahtani", "Fahad Al-Otaibi", "Mohammed Al-Harbi",
    "Nasser Al-Dossari", "Khalid Al-Ghamdi", "Saeed Al-Zahrani",
    "Yousef Al-Mutairi", "Majed Al-Shammari", "Ahmed Al-Anazi",
    "Salem Al-Rashidi", "Omar Al-Shehri", "Hassan Al-Yami",
    "Rashid Al-Malki", "Ibrahim Al-Subaie", "Mansour Al-Qahtani",
    "Waleed Al-Harbi", "Bilal Khan", "Imran Ahmed", "Sameer Khan",
    "Nadeem Ali", "Arif Rahman", "Mustafa Hussain",
]

OWNER_NAMES = [
    "Al Rajhi", "Al Othman", "Al Harbi", "Al Qahtani", "Al Ghamdi",
    "Al Zahrani", "Al Dossari", "Al Mutairi", "Al Shammari", "Al Anazi",
    "Al Rashid", "Al Saleh", "Al Malki", "Al Subaie", "Al Shehri",
]

BUSINESS_PREFIXES = [
    "Al Noor", "Al Waha", "Al Baraka", "Al Safa", "Al Madina",
    "Al Qassim", "Al Riyadh", "Al Jazeera", "Al Khaleej", "Al Nada",
    "Al Nakheel", "Al Rawabi", "Al Tazaj", "Al Dana", "Al Manar",
]

SHOP_CATEGORIES = [
    "Grocery", "Mini Market", "Supermarket", "Restaurant", "Cafe", "Bakery",
    "Butchery", "Cold Store", "Hotel Kitchen", "Catering Kitchen",
]

BUSINESS_SUFFIX_BY_CATEGORY = {
    "Grocery": ["Grocery", "Baqala", "Food Store"],
    "Mini Market": ["Mini Market", "Corner Market", "Baqala"],
    "Supermarket": ["Supermarket", "Hyper Mini", "Market"],
    "Restaurant": ["Restaurant", "Kitchen", "Grill"],
    "Cafe": ["Cafe", "Coffee House", "Roastery"],
    "Bakery": ["Bakery", "Sweets & Bakery", "Oven"],
    "Butchery": ["Butchery", "Meat Shop", "Fresh Meat"],
    "Cold Store": ["Cold Store", "Frozen Foods", "Chilled Foods"],
    "Hotel Kitchen": ["Hotel Kitchen", "Hospitality Supplies"],
    "Catering Kitchen": ["Catering Kitchen", "Banquet Kitchen"],
}

VISIT_DAYS = ["Saturday", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday"]
ORDER_WINDOWS = ["Morning", "Midday", "Afternoon"]
LIFECYCLE_STATES = ["Active", "New", "At Risk", "Dormant", "Churned"]
LIFECYCLE_PROBS = [0.65, 0.10, 0.15, 0.08, 0.02]

# -----------------------------
# Utility functions
# -----------------------------

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    Faker.seed(seed)


def haversine_km(lat1, lng1, lat2, lng2):
    """Great-circle distance without external geospatial dependencies."""
    r = 6371.0088
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlambda = math.radians(lng2 - lng1)
    a = math.sin(dphi/2)**2 + math.cos(phi1) * math.cos(phi2) * math.sin(dlambda/2)**2
    return 2 * r * math.atan2(math.sqrt(a), math.sqrt(1 - a))


def jitter_location(lat, lng, radius_km=2.5):
    lat_jitter = np.random.normal(0, radius_km / 111 / 2)
    lng_jitter = np.random.normal(0, radius_km / (111 * np.cos(np.radians(lat))) / 2)
    return float(lat + lat_jitter), float(lng + lng_jitter)


def random_date_between(start, end):
    days = (end - start).days
    return start + timedelta(days=random.randint(0, days))


def weighted_choice(values, probs):
    return random.choices(values, weights=probs, k=1)[0]


def generate_plate(prefix):
    return f"{prefix}{random.choice(string.ascii_uppercase)} {random.randint(1000, 9999)}"


def performance_multiplier():
    bucket = random.random()
    if bucket < 0.15:
        return round(random.uniform(1.10, 1.20), 2)
    if bucket < 0.85:
        return round(random.uniform(0.95, 1.08), 2)
    return round(random.uniform(0.85, 0.94), 2)


def cold_truck_required(category):
    probs = {
        "Cold Store": 1.00,
        "Butchery": 1.00,
        "Hotel Kitchen": 0.80,
        "Catering Kitchen": 0.75,
        "Restaurant": 0.60,
        "Supermarket": 0.45,
        "Bakery": 0.25,
        "Cafe": 0.20,
        "Grocery": 0.12,
        "Mini Market": 0.12,
    }
    return random.random() < probs[category]


def choose_payment_type(volume_tier):
    credit_prob = {"HIGH": 0.75, "MED": 0.45, "LOW": 0.20}[volume_tier]
    return "credit" if random.random() < credit_prob else "cash"


def generate_credit(volume_tier, payment_type, lifecycle_state):
    if payment_type == "cash":
        return 0.0, 0.0
    limit_ranges = {
        "HIGH": (30000, 120000),
        "MED": (10000, 45000),
        "LOW": (2000, 15000),
    }
    credit_limit = round(random.uniform(*limit_ranges[volume_tier]), 2)
    if lifecycle_state in ["At Risk", "Dormant"]:
        pct = random.uniform(0.55, 1.10)
    elif lifecycle_state == "Churned":
        pct = random.uniform(0.70, 1.10)
    else:
        pct = random.choices(
            [random.uniform(0.05, 0.35), random.uniform(0.35, 0.70), random.uniform(0.70, 1.10)],
            weights=[0.65, 0.25, 0.10],
            k=1,
        )[0]
    return credit_limit, round(credit_limit * pct, 2)


def generate_shop_name(category, locality, used_names):
    suffix = random.choice(BUSINESS_SUFFIX_BY_CATEGORY[category])
    include_locality = random.random() < 0.28
    templates = [
        "{prefix} {suffix}",
        "{owner} {suffix}",
        "{prefix} Fresh {suffix}",
        "{owner} Trading {suffix}",
    ]
    if include_locality:
        templates.extend(["{locality} {suffix}", "{prefix} {locality} {suffix}"])

    # Keep cold-chain suffixes aligned with cold-chain categories.
    if suffix in {"Frozen Foods", "Cold Store", "Chilled Foods"} and category != "Cold Store":
        suffix = random.choice(BUSINESS_SUFFIX_BY_CATEGORY[category])

    for _ in range(50):
        name = random.choice(templates).format(
            prefix=random.choice(BUSINESS_PREFIXES),
            owner=random.choice(OWNER_NAMES),
            locality=locality,
            suffix=suffix,
        )
        if name not in used_names:
            used_names.add(name)
            return name
    name = f"{locality} {suffix} {random.randint(100, 999)}"
    used_names.add(name)
    return name

# -----------------------------
# Generator functions
# -----------------------------

def generate_territories():
    df = pd.DataFrame(TERRITORIES).copy()
    df["default_salesperson"] = None
    df["default_van"] = None
    return df[
        ["territory_id", "territory_name", "warehouse_lat", "warehouse_lng", "warehouse_address",
         "center_lat", "center_lng", "radius_km", "default_salesperson", "default_van"]
    ]


def generate_salespeople(territory_df, salespeople_per_territory=3):
    names = SAUDI_SALESPERSON_NAMES.copy()
    random.shuffle(names)
    rows = []
    for _, ter in territory_df.iterrows():
        code = CITY_CODES[ter.territory_id]
        for i in range(1, salespeople_per_territory + 1):
            rows.append({
                "sales_id": f"SAL_{code}_{i:03d}",
                "name": names.pop() if names else fake.name(),
                "territory_id": ter.territory_id,
                "working_hours_per_day": 8.0,
                "shift_start_time": "09:00",
                "assigned_van": None,
                "active_status": random.random() < 0.93,
                "performance_multiplier": performance_multiplier(),
            })
    return pd.DataFrame(rows)


def generate_vans(territory_df, salesperson_df, backup_vans_per_territory=1):
    rows = []
    for _, ter in territory_df.iterrows():
        n_sales = int((salesperson_df["territory_id"] == ter.territory_id).sum())
        total_vans = n_sales + backup_vans_per_territory
        code = CITY_CODES[ter.territory_id]
        prefix = PLATE_PREFIXES[ter.territory_id]
        for i in range(1, total_vans + 1):
            rows.append({
                "van_id": f"VAN_{code}_{i:03d}",
                "registration_no": generate_plate(prefix),
                "cold_truck_enabled": random.random() < 0.50,
                "territory_id": ter.territory_id,
                "active_status": random.random() < 0.96,
            })
    return pd.DataFrame(rows)


def assign_vans_to_salespeople(salesperson_df, van_df):
    salesperson_df = salesperson_df.copy()
    for territory_id in salesperson_df["territory_id"].unique():
        sp_idx = salesperson_df.index[salesperson_df["territory_id"] == territory_id].tolist()
        vans = van_df[van_df["territory_id"] == territory_id]["van_id"].tolist()
        for idx, van_id in zip(sp_idx, vans):
            salesperson_df.loc[idx, "assigned_van"] = van_id
    return salesperson_df


def assign_defaults(territory_df, salesperson_df, van_df):
    territory_df = territory_df.copy()
    for idx, ter in territory_df.iterrows():
        territory_id = ter.territory_id
        active_sp = salesperson_df[(salesperson_df.territory_id == territory_id) & (salesperson_df.active_status)]
        sp_pool = active_sp if not active_sp.empty else salesperson_df[salesperson_df.territory_id == territory_id]
        default_sp = sp_pool.sort_values("performance_multiplier", ascending=False).iloc[0]
        default_van = default_sp.assigned_van
        if pd.isna(default_van):
            default_van = van_df[van_df.territory_id == territory_id].iloc[0].van_id
        territory_df.loc[idx, "default_salesperson"] = default_sp.sales_id
        territory_df.loc[idx, "default_van"] = default_van
    return territory_df


def generate_customers(territory_df, customers_per_territory=100):
    rows = []
    today = date.today()
    start_acq = today - timedelta(days=5 * 365)
    end_acq = today - timedelta(days=30)

    for _, ter in territory_df.iterrows():
        territory_id = ter.territory_id
        code = CITY_CODES[territory_id]
        used_names = set()
        tiers = ["HIGH"] * 20 + ["MED"] * 30 + ["LOW"] * 50
        random.shuffle(tiers)

        for i in range(1, customers_per_territory + 1):
            locality, base_lat, base_lng = random.choice(LOCALITIES[territory_id])
            for _ in range(100):
                lat, lng = jitter_location(base_lat, base_lng, radius_km=2.5)
                if haversine_km(lat, lng, ter.center_lat, ter.center_lng) <= ter.radius_km:
                    break
            else:
                lat, lng = base_lat, base_lng

            tier = tiers[i - 1]
            lifecycle = weighted_choice(LIFECYCLE_STATES, LIFECYCLE_PROBS)
            category = random.choice(SHOP_CATEGORIES)
            payment_type = choose_payment_type(tier)
            credit_limit, outstanding_balance = generate_credit(tier, payment_type, lifecycle)
            customer_rating = int(random.choices([1, 2, 3, 4, 5], weights=[0.05, 0.10, 0.25, 0.35, 0.25], k=1)[0])

            rows.append({
                "customer_id": f"CUS_{code}_{i:04d}",
                "shop_name": generate_shop_name(category, locality, used_names),
                "gps_lat": round(lat, 6),
                "gps_lng": round(lng, 6),
                "locality": locality,
                "territory_id": territory_id,
                "customer_rating": customer_rating,
                "review_rating": round(float(np.clip(np.random.normal(4.0, 0.55), 2.5, 5.0)), 1),
                "shop_category": category,
                "cold_truck_required": cold_truck_required(category),
                "volume_tier": tier,
                "payment_type": payment_type,
                "credit_limit": credit_limit,
                "outstanding_balance": outstanding_balance,
                "lifecycle_state": lifecycle,
                "acquisition_date": random_date_between(start_acq, end_acq),
                "preferred_visit_day": random.choice(VISIT_DAYS),
                "preferred_order_window": random.choice(ORDER_WINDOWS),
            })
    return pd.DataFrame(rows)


def fridays_between(start_date, end_date):
    cur = start_date
    while cur.weekday() != 4:  # Monday=0, Friday=4
        cur += timedelta(days=1)
    while cur <= end_date:
        yield cur
        cur += timedelta(days=7)


def generate_holidays(territory_df, salesperson_df, van_df, months=3):
    rows = []
    today = date.today()
    start = date(today.year, today.month, 1)
    end = start + timedelta(days=months * 31)
    holiday_id = 1

    # Territory Friday closure rows
    for _, ter in territory_df.iterrows():
        for d in fridays_between(start, end):
            rows.append({
                "holiday_id": f"HOL_{holiday_id:05d}",
                "salesperson_holiday": None,
                "van_holiday": None,
                "territory_holiday": ter.territory_id,
                "from_date": d,
                "to_date": d,
                "reason": "Friday closure",
            })
            holiday_id += 1

        # Common Saudi master calendar events. Dates are approximate placeholders for synthetic data.
        for label, offset_days, duration_days in [
            ("Ramadan adjusted operating hours", 10, 29),
            ("Eid Al-Fitr holiday", 40, 4),
            ("Saudi National Day", 145, 1),
        ]:
            from_d = start + timedelta(days=offset_days)
            to_d = from_d + timedelta(days=duration_days - 1)
            rows.append({
                "holiday_id": f"HOL_{holiday_id:05d}",
                "salesperson_holiday": None,
                "van_holiday": None,
                "territory_holiday": ter.territory_id,
                "from_date": from_d,
                "to_date": to_d,
                "reason": label,
            })
            holiday_id += 1

    # Salesperson leave: 1-2 short leaves each
    for _, sp in salesperson_df.iterrows():
        for _ in range(random.randint(1, 2)):
            from_d = random_date_between(start, end)
            duration = random.choice([1, 1, 2, 3])
            rows.append({
                "holiday_id": f"HOL_{holiday_id:05d}",
                "salesperson_holiday": sp.sales_id,
                "van_holiday": None,
                "territory_holiday": None,
                "from_date": from_d,
                "to_date": from_d + timedelta(days=duration - 1),
                "reason": random.choice(["Annual leave", "Sick leave"]),
            })
            holiday_id += 1

    # Van maintenance: 1 maintenance day per van per month
    for _, van in van_df.iterrows():
        for month_offset in range(months):
            month_start = start + timedelta(days=month_offset * 31)
            from_d = month_start + timedelta(days=random.randint(0, 27))
            rows.append({
                "holiday_id": f"HOL_{holiday_id:05d}",
                "salesperson_holiday": None,
                "van_holiday": van.van_id,
                "territory_holiday": None,
                "from_date": from_d,
                "to_date": from_d,
                "reason": "Van maintenance",
            })
            holiday_id += 1

    return pd.DataFrame(rows)


def generate_config():
    values = {
        "avg_speed_kmh": 32,
        "avg_service_time_min": 22,
        "buffer_pct": 0.15,
        "rfm_window_days": 90,
        "route_partial_prob": 0.08,
        "route_cancel_prob": 0.03,
        "traffic_jam_prob": 0.12,
        "credit_outstanding_cap": 0.85,
        "normal_shift_start_time": "09:00",
        "ramadan_shift_start_time": "10:00",
    }
    return pd.DataFrame([{"config_key": k, "config_value": v} for k, v in values.items()])


def score_from_quantiles(series, higher_is_better=True):
    # qcut can fail on repeated values, so rank first for stable 1-5 scores.
    ranks = series.rank(method="first")
    labels = [1, 2, 3, 4, 5]
    scored = pd.qcut(ranks, q=5, labels=labels).astype(int)
    if not higher_is_better:
        scored = 6 - scored
    return scored


def generate_rfm_scores(customer_df):
    rows = []
    for _, c in customer_df.iterrows():
        tier = c.volume_tier
        lifecycle = c.lifecycle_state

        if tier == "HIGH":
            recency = random.randint(1, 20)
            frequency = random.randint(20, 50)
            monetary = random.uniform(25000, 180000)
        elif tier == "MED":
            recency = random.randint(7, 45)
            frequency = random.randint(8, 25)
            monetary = random.uniform(7000, 55000)
        else:
            recency = random.randint(20, 90)
            frequency = random.randint(1, 12)
            monetary = random.uniform(500, 12000)

        if lifecycle == "New":
            recency = random.randint(1, 14)
            frequency = max(1, int(frequency * random.uniform(0.25, 0.55)))
            monetary *= random.uniform(0.25, 0.60)
        elif lifecycle == "At Risk":
            recency = max(recency, random.randint(45, 100))
            frequency = max(1, int(frequency * random.uniform(0.45, 0.85)))
            monetary *= random.uniform(0.60, 1.00)
        elif lifecycle == "Dormant":
            recency = random.randint(90, 180)
            frequency = max(0, int(frequency * random.uniform(0.10, 0.35)))
            monetary *= random.uniform(0.10, 0.35)
        elif lifecycle == "Churned":
            recency = random.randint(181, 365)
            frequency = random.choice([0, 0, 1])
            monetary *= random.uniform(0.00, 0.10)

        rows.append({
            "customer_id": c.customer_id,
            "recency": int(recency),
            "frequency": int(frequency),
            "monetary": round(float(monetary), 2),
        })

    df = pd.DataFrame(rows)
    df["r_score"] = score_from_quantiles(df["recency"], higher_is_better=False)
    df["f_score"] = score_from_quantiles(df["frequency"], higher_is_better=True)
    df["m_score"] = score_from_quantiles(df["monetary"], higher_is_better=True)
    df["rfm_score"] = df["r_score"].astype(str) + df["f_score"].astype(str) + df["m_score"].astype(str)

    def segment(row):
        r, f, m = row.r_score, row.f_score, row.m_score
        if r >= 4 and f >= 4 and m >= 4:
            return "Champion"
        if f >= 4 and m >= 3:
            return "Loyal"
        if r >= 4 and f in [2, 3]:
            return "Potential Loyalist"
        if r <= 2 and f >= 3:
            return "At Risk"
        if r <= 2 and f <= 2 and m <= 2:
            return "Hibernating"
        return "Need Attention"

    df["segment"] = df.apply(segment, axis=1)
    return df

# -----------------------------
# Validation and reporting
# -----------------------------

def assert_fk(child_df, child_col, parent_df, parent_col):
    missing = set(child_df[child_col].dropna()) - set(parent_df[parent_col])
    assert not missing, f"Broken FK {child_col}: {missing}"


def validate_all(territory_df, salesperson_df, van_df, customer_df, holiday_df, config_df, rfm_scores_df):
    # Foreign keys
    assert_fk(customer_df, "territory_id", territory_df, "territory_id")
    assert_fk(salesperson_df, "territory_id", territory_df, "territory_id")
    assert_fk(van_df, "territory_id", territory_df, "territory_id")
    assert_fk(holiday_df, "territory_holiday", territory_df, "territory_id")
    assert_fk(holiday_df, "salesperson_holiday", salesperson_df, "sales_id")
    assert_fk(holiday_df, "van_holiday", van_df, "van_id")
    assert_fk(rfm_scores_df, "customer_id", customer_df, "customer_id")

    # Primary keys
    assert territory_df["territory_id"].is_unique
    assert salesperson_df["sales_id"].is_unique
    assert van_df["van_id"].is_unique
    assert customer_df["customer_id"].is_unique
    assert holiday_df["holiday_id"].is_unique
    assert rfm_scores_df["customer_id"].is_unique

    # Row counts
    assert len(territory_df) == 3
    assert len(customer_df) == 300
    assert 6 <= len(salesperson_df) <= 9
    assert 9 <= len(van_df) <= 12
    assert len(rfm_scores_df) == 300

    # Same territory checks
    van_territory = van_df.set_index("van_id")["territory_id"].to_dict()
    sp_territory = salesperson_df.set_index("sales_id")["territory_id"].to_dict()
    for _, sp in salesperson_df.iterrows():
        assert van_territory[sp.assigned_van] == sp.territory_id
    for _, ter in territory_df.iterrows():
        assert sp_territory[ter.default_salesperson] == ter.territory_id
        assert van_territory[ter.default_van] == ter.territory_id

    # Business rules
    cash = customer_df["payment_type"] == "cash"
    assert (customer_df.loc[cash, "credit_limit"] == 0).all()
    assert (customer_df.loc[cash, "outstanding_balance"] == 0).all()
    credit = customer_df["payment_type"] == "credit"
    assert (customer_df.loc[credit, "credit_limit"] > 0).all()
    assert customer_df.loc[customer_df.shop_category.isin(["Cold Store", "Butchery"]), "cold_truck_required"].all()

    # Customer coordinates inside territory radius
    ter_lookup = territory_df.set_index("territory_id")
    for _, c in customer_df.iterrows():
        ter = ter_lookup.loc[c.territory_id]
        dist = haversine_km(c.gps_lat, c.gps_lng, ter.center_lat, ter.center_lng)
        assert dist <= ter.radius_km + 1e-6, f"Customer outside radius: {c.customer_id} {dist:.2f}km"

    # No duplicate shop names inside territory
    dupes = customer_df.duplicated(subset=["territory_id", "shop_name"]).sum()
    assert dupes == 0, f"Duplicate shop names inside territory: {dupes}"

    # Tier distribution
    tier_counts = customer_df.groupby(["territory_id", "volume_tier"]).size().unstack(fill_value=0)
    for territory_id in territory_df["territory_id"]:
        assert int(tier_counts.loc[territory_id, "HIGH"]) == 20
        assert int(tier_counts.loc[territory_id, "MED"]) == 30
        assert int(tier_counts.loc[territory_id, "LOW"]) == 50

    return True


def data_quality_report(territory_df, salesperson_df, van_df, customer_df, holiday_df, config_df, rfm_scores_df):
    report = {
        "row_counts": {
            "territory": len(territory_df),
            "salesperson": len(salesperson_df),
            "van": len(van_df),
            "customer": len(customer_df),
            "holiday": len(holiday_df),
            "config": len(config_df),
            "rfm_scores": len(rfm_scores_df),
        },
        "customer_tiers_by_territory": customer_df.groupby(["territory_id", "volume_tier"]).size().unstack(fill_value=0).to_dict(orient="index"),
        "lifecycle_distribution": customer_df["lifecycle_state"].value_counts(normalize=True).round(3).to_dict(),
        "payment_type_distribution": customer_df["payment_type"].value_counts(normalize=True).round(3).to_dict(),
        "cold_truck_required_share": round(float(customer_df["cold_truck_required"].mean()), 3),
        "rfm_segments": rfm_scores_df["segment"].value_counts().to_dict(),
        "validation_status": "passed",
        "generated_at": datetime.now().isoformat(timespec="seconds"),
    }
    return report


def generate_all(seed=42, output_dir="saudi_master_data_output", write_files=True):
    set_seed(seed)

    territory_df = generate_territories()
    salesperson_df = generate_salespeople(territory_df)
    van_df = generate_vans(territory_df, salesperson_df)
    salesperson_df = assign_vans_to_salespeople(salesperson_df, van_df)
    territory_df = assign_defaults(territory_df, salesperson_df, van_df)
    customer_df = generate_customers(territory_df)
    holiday_df = generate_holidays(territory_df, salesperson_df, van_df)
    config_df = generate_config()
    rfm_scores_df = generate_rfm_scores(customer_df)

    validate_all(territory_df, salesperson_df, van_df, customer_df, holiday_df, config_df, rfm_scores_df)
    report = data_quality_report(territory_df, salesperson_df, van_df, customer_df, holiday_df, config_df, rfm_scores_df)

    outputs = {
        "territory": territory_df,
        "salesperson": salesperson_df,
        "van": van_df,
        "customer": customer_df,
        "holiday": holiday_df,
        "config": config_df,
        "rfm_scores": rfm_scores_df,
    }

    if write_files:
        out = Path(output_dir)
        out.mkdir(parents=True, exist_ok=True)
        for name, df in outputs.items():
            df.to_csv(out / f"{name}.csv", index=False)
        with open(out / "data_quality_report.json", "w", encoding="utf-8") as f:
            json.dump(report, f, indent=2, default=str, ensure_ascii=False)
        print(f"Wrote CSV/JSON outputs to: {out.resolve()}")

    return outputs, report

# Generate data
outputs, report = generate_all(seed=42)
territory_df = outputs["territory"]
salesperson_df = outputs["salesperson"]
van_df = outputs["van"]
customer_df = outputs["customer"]
holiday_df = outputs["holiday"]
config_df = outputs["config"]
rfm_scores_df = outputs["rfm_scores"]

print(json.dumps(report, indent=2, default=str, ensure_ascii=False))
# Out:
# Wrote CSV/JSON outputs to: D:\Data Science\Basamh\JP\journey-planner\saudi_master_data_output
# {
#   "row_counts": {
#     "territory": 3,
#     "salesperson": 9,
#     "van": 12,
#     "customer": 300,
#     "holiday": 98,
#     "config": 10,
#     "rfm_scores": 300
#   },
#   "customer_tiers_by_territory": {
#     "TER_DMM": {
#       "HIGH": 20,
#       "LOW": 50,
#       "MED": 30
#     },
#     "TER_JED": {
#       "HIGH": 20,
#       "LOW": 50,
#       "MED": 30
#     },
#     "TER_RUH": {
#       "HIGH": 20,
#       "LOW": 50,
#       "MED": 30
#     }
#   },
#   "lifecycle_distribution": {
#     "Active": 0.65,
#     "New": 0.123,
#     "At Risk": 0.12,
#     "Dormant": 0.103,
#     "Churned": 0.003
#   },
#   "payment_type_distribution": {
#     "cash": 0.637,
#     "credit": 0.363
#   },
#   "cold_truck_required_share": 0.523,
#   "rfm_segments": {
#     "Need Attention": 76,
#     "Champion": 69,
#     "Hibernating": 47,
#     "Loyal": 41,
#     "At Risk": 37,
#     "Potential Loyalist": 30
#   },
#   "validation_status": "passed",
#   "generated_at": "2026-05-27T18:25:53"
# }

# %% [markdown]
# ## Preview generated tables
#
# Run the cells below after generation to inspect samples and distribution checks.

# %%
holiday_df[holiday_df["salesperson_holiday"].notna()]
# Out:
#    holiday_id salesperson_holiday van_holiday territory_holiday   from_date  \
# 51  HOL_00052         SAL_RUH_001         NaN               NaN  2026-07-03
# 52  HOL_00053         SAL_RUH_002         NaN               NaN  2026-06-03
# 53  HOL_00054         SAL_RUH_003         NaN               NaN  2026-06-01
# 54  HOL_00055         SAL_JED_001         NaN               NaN  2026-05-16
# 55  HOL_00056         SAL_JED_002         NaN               NaN  2026-07-09
# 56  HOL_00057         SAL_JED_003         NaN               NaN  2026-07-19
# 57  HOL_00058         SAL_JED_003         NaN               NaN  2026-07-13
# 58  HOL_00059         SAL_DMM_001         NaN               NaN  2026-07-05
# 59  HOL_00060         SAL_DMM_002         NaN               NaN  2026-07-13
# 60  HOL_00061         SAL_DMM_003         NaN               NaN  2026-07-01
# 61  HOL_00062         SAL_DMM_003         NaN               NaN  2026-06-20
#
#        to_date        reason
# 51  2026-07-03  Annual leave
# 52  2026-06-03  Annual leave
# 53  2026-06-02  Annual leave
# 54  2026-05-16    Sick leave
# 55  2026-07-09    Sick leave
# 56  2026-07-20    Sick leave
# 57  2026-07-14    Sick leave
# 58  2026-07-06    Sick leave
# 59  2026-07-13  Annual leave
# 60  2026-07-01    Sick leave
# 61  2026-06-20    Sick leave

# %%
print("Territories")
display(territory_df)

print("Salespeople")
display(salesperson_df.head(10))

print("Vans")
display(van_df.head(10))

print("Customers")
display(customer_df.head(10))

print("RFM scores")
display(rfm_scores_df.head(10))
# Out:
# Territories
#   territory_id  territory_name  warehouse_lat  warehouse_lng  \
# 0      TER_RUH  Riyadh Central        24.5790        46.8237
# 1      TER_JED    Jeddah North        21.3429        39.2357
# 2      TER_DMM    Dammam Metro        26.2926        50.1629
#
#                    warehouse_address  center_lat  center_lng  radius_km  \
# 0            Industrial Area, Riyadh     24.7136     46.6753         25
# 1  Al Khomrah Logistics Area, Jeddah     21.5433     39.1728         22
# 2        2nd Industrial City, Dammam     26.4207     50.0888         20
#
#   default_salesperson  default_van
# 0         SAL_RUH_001  VAN_RUH_001
# 1         SAL_JED_002  VAN_JED_002
# 2         SAL_DMM_002  VAN_DMM_002
# Salespeople
#       sales_id                 name territory_id  working_hours_per_day  \
# 0  SAL_RUH_001          Arif Rahman      TER_RUH                    8.0
# 1  SAL_RUH_002    Nasser Al-Dossari      TER_RUH                    8.0
# 2  SAL_RUH_003  Abdullah Al-Qahtani      TER_RUH                    8.0
# 3  SAL_JED_001       Ahmed Al-Anazi      TER_JED                    8.0
# 4  SAL_JED_002    Majed Al-Shammari      TER_JED                    8.0
# 5  SAL_JED_003          Imran Ahmed      TER_JED                    8.0
# 6  SAL_DMM_001     Khalid Al-Ghamdi      TER_DMM                    8.0
# 7  SAL_DMM_002       Hassan Al-Yami      TER_DMM                    8.0
# 8  SAL_DMM_003      Fahad Al-Otaibi      TER_DMM                    8.0
#
#   shift_start_time assigned_van  active_status  performance_multiplier
# 0            09:00  VAN_RUH_001           True                    1.04
# 1            09:00  VAN_RUH_002           True                    0.99
# 2            09:00  VAN_RUH_003           True                    0.97
# 3            09:00  VAN_JED_001           True                    0.98
# 4            09:00  VAN_JED_002           True                    1.14
# 5            09:00  VAN_JED_003           True                    0.98
# 6            09:00  VAN_DMM_001           True                    0.97
# 7            09:00  VAN_DMM_002           True                    1.13
# 8            09:00  VAN_DMM_003           True                    0.88
# Vans
#         van_id registration_no  cold_truck_enabled territory_id  active_status
# 0  VAN_RUH_001        RUG 2139                True      TER_RUH           True
# 1  VAN_RUH_002        RUJ 2307               False      TER_RUH           True
# 2  VAN_RUH_003        RUM 5554                True      TER_RUH           True
# 3  VAN_RUH_004        RUF 7065                True      TER_RUH           True
# 4  VAN_JED_001        JEW 2169               False      TER_JED           True
# 5  VAN_JED_002        JEX 5010                True      TER_JED           True
# 6  VAN_JED_003        JEU 4598               False      TER_JED           True
# 7  VAN_JED_004        JEY 1916                True      TER_JED           True
# 8  VAN_DMM_001        DMK 7572                True      TER_DMM           True
# 9  VAN_DMM_002        DMS 6155                True      TER_DMM           True
# Customers
#     customer_id                    shop_name    gps_lat    gps_lng  \
# 0  CUS_RUH_0001    Al Waha Fresh Mini Market  24.769194  46.600485
# 1  CUS_RUH_0002    Al Othman Banquet Kitchen  24.780751  46.599296
# 2  CUS_RUH_0003  Al Qassim Al Yasmin Grocery  24.844884  46.639722
# 3  CUS_RUH_0004           Al Waha Fresh Meat  24.769710  46.596453
# 4  CUS_RUH_0005      Al Manar Fresh Butchery  24.829825  46.606460
# 5  CUS_RUH_0006    Al Shammari Chilled Foods  24.757268  46.589639
# 6  CUS_RUH_0007                  Olaya Grill  24.701275  46.657092
# 7  CUS_RUH_0008                  Hittin Cafe  24.761057  46.603037
# 8  CUS_RUH_0009    Al Nada Fresh Mini Market  24.661470  46.736475
# 9  CUS_RUH_0010        Al Ghamdi Mini Market  24.705431  46.703755
#
#           locality territory_id  customer_rating  review_rating  \
# 0           Hittin      TER_RUH                2            4.4
# 1           Hittin      TER_RUH                3            3.9
# 2        Al Yasmin      TER_RUH                5            3.7
# 3           Hittin      TER_RUH                2            3.7
# 4        Al Yasmin      TER_RUH                3            3.1
# 5           Hittin      TER_RUH                2            4.2
# 6            Olaya      TER_RUH                5            4.8
# 7           Hittin      TER_RUH                3            3.2
# 8         Al Malaz      TER_RUH                3            3.4
# 9  Al Sulaymaniyah      TER_RUH                2            3.8
#
#       shop_category  cold_truck_required volume_tier payment_type  \
# 0       Mini Market                False         LOW         cash
# 1  Catering Kitchen                 True         MED         cash
# 2           Grocery                False         MED         cash
# 3          Butchery                 True        HIGH       credit
# 4          Butchery                 True         MED         cash
# 5        Cold Store                 True         LOW       credit
# 6        Restaurant                 True         LOW         cash
# 7              Cafe                 True         MED       credit
# 8       Mini Market                False         LOW         cash
# 9       Mini Market                False         MED         cash
#
#    credit_limit  outstanding_balance lifecycle_state acquisition_date  \
# 0          0.00                 0.00          Active       2025-02-26
# 1          0.00                 0.00          Active       2023-05-23
# 2          0.00                 0.00         At Risk       2022-10-19
# 3      71636.53             26962.89          Active       2022-09-24
# 4          0.00                 0.00          Active       2023-01-02
# 5       5857.20              3237.35             New       2022-06-12
# 6          0.00                 0.00             New       2025-02-02
# 7      35066.71              4264.31          Active       2022-08-07
# 8          0.00                 0.00         Dormant       2021-06-13
# 9          0.00                 0.00         Dormant       2025-06-05
#
#   preferred_visit_day preferred_order_window
# 0             Tuesday                Morning
# 1             Tuesday                 Midday
# 2              Sunday                Morning
# 3              Sunday                 Midday
# 4             Tuesday              Afternoon
# 5            Saturday              Afternoon
# 6           Wednesday              Afternoon
# 7           Wednesday                 Midday
# 8            Thursday              Afternoon
# 9              Monday                Morning
# RFM scores
#     customer_id  recency  frequency  monetary  r_score  f_score  m_score  \
# 0  CUS_RUH_0001       71          5   5683.38        2        2        2
# 1  CUS_RUH_0002       43         12  54005.08        3        4        5
# 2  CUS_RUH_0003       96          5  32151.46        1        2        4
# 3  CUS_RUH_0004       13         26  47605.78        4        5        5
# 4  CUS_RUH_0005       16         23  45672.08        4        5        5
# 5  CUS_RUH_0006       14          3   2728.57        4        1        1
# 6  CUS_RUH_0007        9          4   1053.56        5        2        1
# 7  CUS_RUH_0008       13         13   9881.75        4        4        3
# 8  CUS_RUH_0009      102          1   1863.86        1        1        1
# 9  CUS_RUH_0010      122          3   6879.02        1        1        2
#
#   rfm_score             segment
# 0       222         Hibernating
# 1       345               Loyal
# 2       124      Need Attention
# 3       455            Champion
# 4       455            Champion
# 5       411      Need Attention
# 6       521  Potential Loyalist
# 7       443               Loyal
# 8       111         Hibernating
# 9       112         Hibernating

# %%
print("Tier counts per territory")
display(customer_df.groupby(["territory_id", "volume_tier"]).size().unstack(fill_value=0))

print("Lifecycle distribution")
display(customer_df["lifecycle_state"].value_counts(normalize=True).rename("share").round(3))

print("RFM segments")
display(rfm_scores_df["segment"].value_counts())

print("Output files")
for path in sorted(Path("saudi_master_data_output").glob("*")):
    print(path)
# Out:
# Tier counts per territory
# volume_tier   HIGH  LOW  MED
# territory_id
# TER_DMM         20   50   30
# TER_JED         20   50   30
# TER_RUH         20   50   30
# Lifecycle distribution
# lifecycle_state
# Active     0.650
# New        0.123
# At Risk    0.120
# Dormant    0.103
# Churned    0.003
# Name: share, dtype: float64
# RFM segments
# segment
# Need Attention        76
# Champion              69
# Hibernating           47
# Loyal                 41
# At Risk               37
# Potential Loyalist    30
# Name: count, dtype: int64
# Output files
# saudi_master_data_output\config.csv
# saudi_master_data_output\customer.csv
# saudi_master_data_output\data_quality_report.json
# saudi_master_data_output\holiday.csv
# saudi_master_data_output\rfm_scores.csv
# saudi_master_data_output\salesperson.csv
# saudi_master_data_output\territory.csv
# saudi_master_data_output\van.csv

# %% [markdown]
# ## Notes
#
# - This notebook intentionally excludes route, visit, and basket-level transaction tables.
# - The holiday dates are synthetic placeholders suitable for master-data demos. For production Saudi holiday calendars, replace those placeholder rows with an official calendar source.
# - `generate_all(seed=42)` is deterministic for repeatable demos. Change the seed to create a different synthetic dataset.

# %%
from saudi_multi_salesperson_scheduler import MultiSalespersonScheduler

result = MultiSalespersonScheduler().create_schedules(
    customer_df=customer_df,
    rfm_scores_df=rfm_scores_df,
    salesperson_df=salesperson_df,
    holiday_df=holiday_df,
    territory_df=territory_df,
    config_df=config_df,
    van_df=van_df,
    month_start_date="2026-06-01",
)
# Out:
# Territory TER_RUH: assigning 100 customers to 3 salespeople via KMeans clustering...
#   SAL_RUH_001 → 49 customers assigned
#   SAL_RUH_002 → 17 customers assigned
#   SAL_RUH_003 → 34 customers assigned
#
#   Scheduling SAL_RUH_001 (49 customers, 16 valid days)...
#   [SAL_RUH_001] OPTIMAL | obj=80767315
#
#   Scheduling SAL_RUH_002 (17 customers, 16 valid days)...
#   [SAL_RUH_002] OPTIMAL | obj=48637135
#
#   Scheduling SAL_RUH_003 (34 customers, 16 valid days)...
#   [SAL_RUH_003] OPTIMAL | obj=48495150
#
# Territory TER_JED: assigning 100 customers to 3 salespeople via KMeans clustering...
#   SAL_JED_001 → 21 customers assigned
#   SAL_JED_002 → 58 customers assigned
#   SAL_JED_003 → 21 customers assigned
#
#   Scheduling SAL_JED_001 (21 customers, 16 valid days)...
#   [SAL_JED_001] OPTIMAL | obj=52464326
#
#   Scheduling SAL_JED_002 (58 customers, 16 valid days)...
#
#   Scheduling SAL_JED_003 (21 customers, 16 valid days)...
#   [SAL_JED_003] OPTIMAL | obj=48432255
#
# Territory TER_DMM: assigning 100 customers to 3 salespeople via KMeans clustering...
#   SAL_DMM_001 → 37 customers assigned
#   SAL_DMM_002 → 28 customers assigned
#   SAL_DMM_003 → 35 customers assigned
#
#   Scheduling SAL_DMM_001 (37 customers, 16 valid days)...
#   [SAL_DMM_001] OPTIMAL | obj=80759405
#
#   Scheduling SAL_DMM_002 (28 customers, 16 valid days)...
#   [SAL_DMM_002] OPTIMAL | obj=76789433
#
#   Scheduling SAL_DMM_003 (35 customers, 15 valid days)...
#   [SAL_DMM_003] OPTIMAL | obj=75796210

# %%
display(result)
# Out:
# MultiScheduleResult(detailed_schedule=    schedule_date     sales_id territory_id   customer_id  \
# 0      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0002
# 1      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0031
# 2      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0046
# 3      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0073
# 4      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0094
# ..            ...          ...          ...           ...
# 502    2026-06-29  SAL_RUH_003      TER_RUH  CUS_RUH_0080
# 503    2026-06-29  SAL_RUH_003      TER_RUH  CUS_RUH_0085
# 504    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0005
# 505    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0019
# 506    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0085
#
#                                shop_name         locality    gps_lat  \
# 0               Al Safa Catering Kitchen         Al Shati  26.485366
# 1                 Al Nakheel Fresh Grill         Al Shati  26.466035
# 2          Al Subaie Trading Mini Market     Al Mazruiyah  26.453422
# 3               Al Dana Catering Kitchen         Al Shati  26.473107
# 4                    Al Tazaj Fresh Meat    Al Faisaliyah  26.441583
# ..                                   ...              ...        ...
# 502  Al Noor Hittin Hospitality Supplies           Hittin  24.765700
# 503              Al Anazi Trading Bakery  Al Sulaymaniyah  24.725098
# 504              Al Manar Fresh Butchery        Al Yasmin  24.829825
# 505               Al Madina Coffee House  Al Sulaymaniyah  24.712810
# 506              Al Anazi Trading Bakery  Al Sulaymaniyah  24.725098
#
#        gps_lng         segment lifecycle_state  cold_truck_required  \
# 0    50.117601        Champion          Active                 True
# 1    50.126984  Need Attention          Active                False
# 2    50.099420  Need Attention         At Risk                False
# 3    50.123592         At Risk          Active                False
# 4    50.110377  Need Attention             New                 True
# ..         ...             ...             ...                  ...
# 502  46.593993  Need Attention             New                 True
# 503  46.723998        Champion          Active                False
# 504  46.606460        Champion          Active                 True
# 505  46.722744        Champion          Active                False
# 506  46.723998        Champion          Active                False
#
#      estimated_visit_minutes  estimated_travel_minutes
# 0                         22                        82
# 1                         22                        73
# 2                         22                        71
# 3                         22                        76
# 4                         22                        65
# ..                       ...                       ...
# 502                       22                       116
# 503                       22                        71
# 504                       22                       133
# 505                       22                        67
# 506                       22                        71
#
# [507 rows x 13 columns], daily_schedule=    schedule_date     sales_id territory_id  \
# 0      2026-06-09  SAL_DMM_001      TER_DMM
# 1      2026-06-14  SAL_DMM_001      TER_DMM
# 2      2026-06-15  SAL_DMM_001      TER_DMM
# 3      2026-06-16  SAL_DMM_001      TER_DMM
# 4      2026-06-17  SAL_DMM_001      TER_DMM
# ..            ...          ...          ...
# 121    2026-06-25  SAL_RUH_003      TER_RUH
# 122    2026-06-27  SAL_RUH_003      TER_RUH
# 123    2026-06-28  SAL_RUH_003      TER_RUH
# 124    2026-06-29  SAL_RUH_003      TER_RUH
# 125    2026-06-30  SAL_RUH_003      TER_RUH
#
#                                          customer_list  customer_count  \
# 0    [CUS_DMM_0094, CUS_DMM_0046, CUS_DMM_0031, CUS...               5
# 1    [CUS_DMM_0011, CUS_DMM_0067, CUS_DMM_0056, CUS...               5
# 2    [CUS_DMM_0029, CUS_DMM_0099, CUS_DMM_0009, CUS...               5
# 3    [CUS_DMM_0067, CUS_DMM_0001, CUS_DMM_0046, CUS...               5
# 4    [CUS_DMM_0080, CUS_DMM_0097, CUS_DMM_0087, CUS...               5
# ..                                                 ...             ...
# 121         [CUS_RUH_0023, CUS_RUH_0051, CUS_RUH_0058]               3
# 122         [CUS_RUH_0035, CUS_RUH_0085, CUS_RUH_0006]               3
# 123         [CUS_RUH_0035, CUS_RUH_0041, CUS_RUH_0027]               3
# 124         [CUS_RUH_0019, CUS_RUH_0085, CUS_RUH_0080]               3
# 125         [CUS_RUH_0019, CUS_RUH_0085, CUS_RUH_0005]               3
#
#                                            route_order  total_visit_min  \
# 0    [Al Tazaj Fresh Meat, Al Subaie Trading Mini M...              110
# 1    [Al Rajhi Trading Mini Market, Al Rajhi Tradin...              110
# 2    [Al Othman Trading Butchery, Al Tazaj Al Mazru...              110
# 3    [Al Rajhi Trading Sweets & Bakery, Al Shehri T...              110
# 4    [Al Dana Fresh Food Store, Al Madina Coffee Ho...              110
# ..                                                 ...              ...
# 121  [Al Tazaj Fresh Restaurant, Al Shehri Trading ...               66
# 122  [Al Malki Trading Catering Kitchen, Al Anazi T...               66
# 123  [Al Malki Trading Catering Kitchen, Al Baraka ...               66
# 124  [Al Madina Coffee House, Al Anazi Trading Bake...               66
# 125  [Al Madina Coffee House, Al Anazi Trading Bake...               66
#
#      total_travel_min
# 0                 367
# 1                 330
# 2                 366
# 3                 365
# 4                 364
# ..                ...
# 121               372
# 122               253
# 123               307
# 124               254
# 125               271
#
# [126 rows x 8 columns], salesperson_results={'SAL_RUH_001': SalespersonScheduleResult(sales_id='SAL_RUH_001', territory_id='TER_RUH', detailed_schedule=   schedule_date     sales_id territory_id   customer_id  \
# 0     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0021
# 1     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0046
# 2     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0067
# 3     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0075
# 4     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0093
# ..           ...          ...          ...           ...
# 75    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0021
# 76    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0054
# 77    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0062
# 78    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0090
# 79    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0093
#
#                               shop_name         locality    gps_lat  \
# 0          Al Subaie Trading Restaurant         Al Malaz  24.662204
# 1               Al Qassim Chilled Foods  Al Sulaymaniyah  24.718654
# 2                   Al Noor Mini Market  Al Sulaymaniyah  24.701856
# 3           Al Nada Fresh Chilled Foods         Al Malaz  24.675328
# 4                 Al Jazeera Fresh Cafe           Hittin  24.765842
# ..                                  ...              ...        ...
# 75         Al Subaie Trading Restaurant         Al Malaz  24.662204
# 76  Al Manar Al Sulaymaniyah Cold Store  Al Sulaymaniyah  24.708594
# 77          Al Malki Trading Cold Store  Al Sulaymaniyah  24.706633
# 78                     Al Nakheel Grill  Al Sulaymaniyah  24.685095
# 79                Al Jazeera Fresh Cafe           Hittin  24.765842
#
#       gps_lng         segment lifecycle_state  cold_truck_required  \
# 0   46.732799        Champion             New                False
# 1   46.701491  Need Attention          Active                 True
# 2   46.697032        Champion          Active                False
# 3   46.715115     Hibernating          Active                 True
# 4   46.594756        Champion          Active                False
# ..        ...             ...             ...                  ...
# 75  46.732799        Champion             New                False
# 76  46.699118        Champion          Active                 True
# 77  46.708430     Hibernating         At Risk                 True
# 78  46.705745        Champion          Active                False
# 79  46.594756        Champion          Active                False
#
#     estimated_visit_minutes  estimated_travel_minutes
# 0                        22                        48
# 1                        22                        74
# 2                        22                        70
# 3                        22                        57
# 4                        22                       116
# ..                      ...                       ...
# 75                       22                        48
# 76                       22                        71
# 77                       22                        68
# 78                       22                        62
# 79                       22                       116
#
# [80 rows x 13 columns], daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_RUH_001      TER_RUH
# 1     2026-06-14  SAL_RUH_001      TER_RUH
# 2     2026-06-15  SAL_RUH_001      TER_RUH
# 3     2026-06-16  SAL_RUH_001      TER_RUH
# 4     2026-06-17  SAL_RUH_001      TER_RUH
# 5     2026-06-18  SAL_RUH_001      TER_RUH
# 6     2026-06-20  SAL_RUH_001      TER_RUH
# 7     2026-06-21  SAL_RUH_001      TER_RUH
# 8     2026-06-22  SAL_RUH_001      TER_RUH
# 9     2026-06-23  SAL_RUH_001      TER_RUH
# 10    2026-06-24  SAL_RUH_001      TER_RUH
# 11    2026-06-25  SAL_RUH_001      TER_RUH
# 12    2026-06-27  SAL_RUH_001      TER_RUH
# 13    2026-06-28  SAL_RUH_001      TER_RUH
# 14    2026-06-29  SAL_RUH_001      TER_RUH
# 15    2026-06-30  SAL_RUH_001      TER_RUH
#
#                                         customer_list  customer_count  \
# 0   [CUS_RUH_0021, CUS_RUH_0075, CUS_RUH_0067, CUS...               5
# 1   [CUS_RUH_0014, CUS_RUH_0034, CUS_RUH_0029, CUS...               5
# 2   [CUS_RUH_0036, CUS_RUH_0061, CUS_RUH_0020, CUS...               5
# 3   [CUS_RUH_0021, CUS_RUH_0017, CUS_RUH_0100, CUS...               5
# 4   [CUS_RUH_0043, CUS_RUH_0063, CUS_RUH_0067, CUS...               5
# 5   [CUS_RUH_0043, CUS_RUH_0090, CUS_RUH_0020, CUS...               5
# 6   [CUS_RUH_0017, CUS_RUH_0070, CUS_RUH_0054, CUS...               5
# 7   [CUS_RUH_0015, CUS_RUH_0090, CUS_RUH_0029, CUS...               5
# 8   [CUS_RUH_0012, CUS_RUH_0050, CUS_RUH_0020, CUS...               5
# 9   [CUS_RUH_0021, CUS_RUH_0060, CUS_RUH_0067, CUS...               5
# 10  [CUS_RUH_0043, CUS_RUH_0017, CUS_RUH_0067, CUS...               5
# 11  [CUS_RUH_0018, CUS_RUH_0011, CUS_RUH_0087, CUS...               5
# 12  [CUS_RUH_0017, CUS_RUH_0066, CUS_RUH_0054, CUS...               5
# 13  [CUS_RUH_0090, CUS_RUH_0029, CUS_RUH_0039, CUS...               5
# 14  [CUS_RUH_0012, CUS_RUH_0094, CUS_RUH_0011, CUS...               5
# 15  [CUS_RUH_0021, CUS_RUH_0090, CUS_RUH_0062, CUS...               5
#
#                                           route_order  total_visit_min  \
# 0   [Al Subaie Trading Restaurant, Al Nada Fresh C...              110
# 1   [Al Rashid Trading Market, Al Jazeera Baqala, ...              110
# 2   [Al Qassim Fresh Banquet Kitchen, Al Manar Fre...              110
# 3   [Al Subaie Trading Restaurant, Al Rawabi Roast...              110
# 4   [Al Ghamdi Trading Hospitality Supplies, Al Wa...              110
# 5   [Al Ghamdi Trading Hospitality Supplies, Al Na...              110
# 6   [Al Rawabi Roastery, Al Khaleej Al Sulaymaniya...              110
# 7   [Al Ghamdi Trading Corner Market, Al Nakheel G...              110
# 8   [Al Manar Al Malaz Hotel Kitchen, Al Dana Fres...              110
# 9   [Al Subaie Trading Restaurant, Al Shehri Food ...              110
# 10  [Al Ghamdi Trading Hospitality Supplies, Al Ra...              110
# 11  [Al Rawabi Baqala, Al Noor Fresh Cafe, Al Nakh...              110
# 12  [Al Rawabi Roastery, Al Khaleej Fresh Cold Sto...              110
# 13  [Al Nakheel Grill, Al Tazaj Meat Shop, Al Anaz...              110
# 14  [Al Manar Al Malaz Hotel Kitchen, Al Othman Sw...              110
# 15  [Al Subaie Trading Restaurant, Al Nakheel Gril...              110
#
#     total_travel_min
# 0                365
# 1                368
# 2                363
# 3                362
# 4                344
# 5                322
# 6                354
# 7                369
# 8                344
# 9                360
# 10               332
# 11               360
# 12               358
# 13               361
# 14               298
# 15               365  , assigned_customers=     customer_id                                shop_name    gps_lat  \
# 0   CUS_RUH_0004                       Al Waha Fresh Meat  24.769710
# 3   CUS_RUH_0021             Al Subaie Trading Restaurant  24.662204
# 6   CUS_RUH_0037                             Al Dana Oven  24.714400
# 9   CUS_RUH_0049                Al Shammari Corner Market  24.714427
# 12  CUS_RUH_0067                      Al Noor Mini Market  24.701856
# 15  CUS_RUH_0090                         Al Nakheel Grill  24.685095
# 18  CUS_RUH_0093                    Al Jazeera Fresh Cafe  24.765842
# 23  CUS_RUH_0007                              Olaya Grill  24.701275
# 25  CUS_RUH_0012          Al Manar Al Malaz Hotel Kitchen  24.655689
# 26  CUS_RUH_0016              Al Subaie Trading Meat Shop  24.703394
# 27  CUS_RUH_0017                       Al Rawabi Roastery  24.671470
# 28  CUS_RUH_0020                  Al Madina Chilled Foods  24.697718
# 33  CUS_RUH_0028    Al Rajhi Trading Hospitality Supplies  24.671622
# 34  CUS_RUH_0029                       Al Tazaj Meat Shop  24.692095
# 35  CUS_RUH_0030                           Al Tazaj Grill  24.715202
# 36  CUS_RUH_0031                 Al Anazi Banquet Kitchen  24.712593
# 37  CUS_RUH_0036          Al Qassim Fresh Banquet Kitchen  24.672150
# 38  CUS_RUH_0039                      Al Anazi Fresh Meat  24.709334
# 41  CUS_RUH_0043   Al Ghamdi Trading Hospitality Supplies  24.656445
# 43  CUS_RUH_0046                  Al Qassim Chilled Foods  24.718654
# 44  CUS_RUH_0047  Al Mutairi Trading Hospitality Supplies  24.720661
# 45  CUS_RUH_0048                      Al Harbi Cold Store  24.682320
# 47  CUS_RUH_0054      Al Manar Al Sulaymaniyah Cold Store  24.708594
# 51  CUS_RUH_0062              Al Malki Trading Cold Store  24.706633
# 52  CUS_RUH_0063               Al Waha Fresh Frozen Foods  24.706529
# 53  CUS_RUH_0065                    Al Dana Hotel Kitchen  24.713911
# 54  CUS_RUH_0066              Al Khaleej Fresh Cold Store  24.705539
# 55  CUS_RUH_0068                  Al Shehri Hotel Kitchen  24.717815
# 58  CUS_RUH_0075              Al Nada Fresh Chilled Foods  24.675328
# 63  CUS_RUH_0082                 Al Malki Banquet Kitchen  24.721249
# 65  CUS_RUH_0087              Al Nakheel Fresh Hyper Mini  24.716498
# 66  CUS_RUH_0088                 Al Zahrani Hotel Kitchen  24.710830
# 67  CUS_RUH_0095                          Al Manar Market  24.719061
# 70  CUS_RUH_0100                          Al Harbi Market  24.704661
# 73  CUS_RUH_0009                Al Nada Fresh Mini Market  24.661470
# 74  CUS_RUH_0010                    Al Ghamdi Mini Market  24.705431
# 75  CUS_RUH_0011                       Al Noor Fresh Cafe  24.694424
# 76  CUS_RUH_0014                 Al Rashid Trading Market  24.669817
# 77  CUS_RUH_0015          Al Ghamdi Trading Corner Market  24.666298
# 78  CUS_RUH_0018                         Al Rawabi Baqala  24.663263
# 82  CUS_RUH_0034                        Al Jazeera Baqala  24.664958
# 84  CUS_RUH_0050               Al Dana Fresh Coffee House  24.652730
# 85  CUS_RUH_0055                    Al Madina Mini Market  24.724547
# 87  CUS_RUH_0060                     Al Shehri Food Store  24.683969
# 88  CUS_RUH_0061      Al Manar Fresh Hospitality Supplies  24.674646
# 89  CUS_RUH_0064                        Al Baraka Kitchen  24.684141
# 90  CUS_RUH_0070        Al Khaleej Al Sulaymaniyah Baqala  24.706986
# 98  CUS_RUH_0094                Al Othman Sweets & Bakery  24.663261
# 99  CUS_RUH_0099                             Olaya Baqala  24.715520
#
#       gps_lng         locality territory_id  customer_rating  review_rating  \
# 0   46.596453           Hittin      TER_RUH                2            3.7
# 3   46.732799         Al Malaz      TER_RUH                2            3.4
# 6   46.673677            Olaya      TER_RUH                4            2.9
# 9   46.684292            Olaya      TER_RUH                3            3.3
# 12  46.697032  Al Sulaymaniyah      TER_RUH                5            4.2
# 15  46.705745  Al Sulaymaniyah      TER_RUH                5            4.1
# 18  46.594756           Hittin      TER_RUH                2            4.0
# 23  46.657092            Olaya      TER_RUH                5            4.8
# 25  46.745293         Al Malaz      TER_RUH                4            3.3
# 26  46.668890            Olaya      TER_RUH                5            4.6
# 27  46.713252         Al Malaz      TER_RUH                2            4.2
# 28  46.715306  Al Sulaymaniyah      TER_RUH                4            4.5
# 33  46.753414         Al Malaz      TER_RUH                1            3.7
# 34  46.704980  Al Sulaymaniyah      TER_RUH                2            4.5
# 35  46.668033            Olaya      TER_RUH                3            4.3
# 36  46.686608            Olaya      TER_RUH                5            3.6
# 37  46.758474         Al Malaz      TER_RUH                4            4.1
# 38  46.678338            Olaya      TER_RUH                4            4.0
# 41  46.728082         Al Malaz      TER_RUH                4            4.1
# 43  46.701491  Al Sulaymaniyah      TER_RUH                5            3.8
# 44  46.659342            Olaya      TER_RUH                2            4.1
# 45  46.715180         Al Malaz      TER_RUH                4            4.1
# 47  46.699118  Al Sulaymaniyah      TER_RUH                1            4.4
# 51  46.708430  Al Sulaymaniyah      TER_RUH                2            4.4
# 52  46.710297  Al Sulaymaniyah      TER_RUH                4            3.5
# 53  46.659157            Olaya      TER_RUH                4            4.1
# 54  46.700244  Al Sulaymaniyah      TER_RUH                5            4.1
# 55  46.688026            Olaya      TER_RUH                3            4.6
# 58  46.715115         Al Malaz      TER_RUH                2            3.7
# 63  46.659721            Olaya      TER_RUH                2            3.8
# 65  46.684203            Olaya      TER_RUH                5            3.5
# 66  46.634420            Olaya      TER_RUH                3            3.4
# 67  46.695857  Al Sulaymaniyah      TER_RUH                5            5.0
# 70  46.721276  Al Sulaymaniyah      TER_RUH                4            4.3
# 73  46.736475         Al Malaz      TER_RUH                3            3.4
# 74  46.703755  Al Sulaymaniyah      TER_RUH                2            3.8
# 75  46.734160  Al Sulaymaniyah      TER_RUH                5            4.0
# 76  46.744251         Al Malaz      TER_RUH                1            4.1
# 77  46.731369         Al Malaz      TER_RUH                1            3.2
# 78  46.726712         Al Malaz      TER_RUH                5            4.3
# 82  46.717561         Al Malaz      TER_RUH                4            3.8
# 84  46.741568         Al Malaz      TER_RUH                5            4.2
# 85  46.664426            Olaya      TER_RUH                4            4.5
# 87  46.731820         Al Malaz      TER_RUH                4            5.0
# 88  46.724478         Al Malaz      TER_RUH                3            3.4
# 89  46.705665  Al Sulaymaniyah      TER_RUH                4            4.5
# 90  46.717584  Al Sulaymaniyah      TER_RUH                3            5.0
# 98  46.736507         Al Malaz      TER_RUH                4            4.4
# 99  46.666010            Olaya      TER_RUH                4            4.5
#
#        shop_category  cold_truck_required  ... preferred_order_window recency  \
# 0           Butchery                 True  ...                 Midday      13
# 3         Restaurant                False  ...              Afternoon       8
# 6             Bakery                False  ...                 Midday       8
# 9        Mini Market                False  ...              Afternoon      11
# 12       Mini Market                False  ...                Morning       5
# 15        Restaurant                False  ...              Afternoon       3
# 18              Cafe                False  ...                Morning      17
# 23        Restaurant                 True  ...              Afternoon       9
# 25     Hotel Kitchen                 True  ...              Afternoon      11
# 26          Butchery                 True  ...                 Midday      10
# 27              Cafe                 True  ...              Afternoon      12
# 28        Cold Store                 True  ...                Morning      24
# 33     Hotel Kitchen                 True  ...                 Midday     224
# 34          Butchery                 True  ...                Morning      29
# 35        Restaurant                 True  ...              Afternoon      79
# 36  Catering Kitchen                 True  ...                Morning     179
# 37  Catering Kitchen                 True  ...                Morning      37
# 38          Butchery                 True  ...                Morning      90
# 41     Hotel Kitchen                 True  ...              Afternoon      41
# 43        Cold Store                 True  ...              Afternoon      44
# 44     Hotel Kitchen                 True  ...              Afternoon       2
# 45        Cold Store                 True  ...                 Midday     101
# 47        Cold Store                 True  ...                 Midday      22
# 51        Cold Store                 True  ...                Morning      95
# 52        Cold Store                 True  ...              Afternoon      51
# 53     Hotel Kitchen                 True  ...              Afternoon      40
# 54        Cold Store                 True  ...                 Midday      28
# 55     Hotel Kitchen                 True  ...                Morning      65
# 58        Cold Store                 True  ...              Afternoon      90
# 63  Catering Kitchen                 True  ...                Morning      34
# 65       Supermarket                 True  ...                 Midday      66
# 66     Hotel Kitchen                 True  ...              Afternoon      11
# 67       Supermarket                 True  ...              Afternoon      88
# 70       Supermarket                 True  ...                Morning      84
# 73       Mini Market                False  ...              Afternoon     102
# 74       Mini Market                False  ...                Morning     122
# 75              Cafe                False  ...                 Midday      64
# 76       Supermarket                False  ...                 Midday      85
# 77       Mini Market                False  ...                Morning      56
# 78       Mini Market                False  ...                 Midday      60
# 82       Mini Market                False  ...                 Midday      61
# 84              Cafe                False  ...              Afternoon      95
# 85       Mini Market                False  ...              Afternoon      76
# 87           Grocery                False  ...                Morning      66
# 88     Hotel Kitchen                False  ...              Afternoon      47
# 89        Restaurant                False  ...                Morning     109
# 90       Mini Market                False  ...                 Midday      22
# 98            Bakery                False  ...                Morning      78
# 99       Mini Market                False  ...              Afternoon      41
#
#     frequency   monetary r_score f_score m_score rfm_score  \
# 0          26   47605.78       4       5       5       455
# 3          16   36457.16       5       4       4       544
# 6          10   54875.52       5       3       5       535
# 9          33   73294.39       5       5       5       555
# 12         42  108134.77       5       5       5       555
# 15         34  149158.09       5       5       5       555
# 18         21  138816.55       4       4       5       445
# 23          4    1053.56       5       2       1       521
# 25          4    4222.25       5       2       2       522
# 26          2    4403.41       5       1       2       512
# 27         13   23494.02       4       4       4       444
# 28         22   44486.75       4       5       4       454
# 33          0      23.05       1       1       1       111
# 34         18   48483.57       3       4       5       345
# 35          9   11250.86       2       3       3       233
# 36          5    3340.47       1       2       1       121
# 37          6    3797.77       3       3       2       332
# 38          3    1867.89       1       1       1       111
# 41         16   26819.39       3       4       4       344
# 43          6     723.05       3       3       1       331
# 44          3     221.65       5       1       1       511
# 45          1     132.77       1       1       1       111
# 47         20   44018.82       4       4       4       444
# 51          3     436.19       1       1       1       111
# 52          1   11641.60       3       1       3       313
# 53          8    1551.12       3       3       1       331
# 54          9    9869.21       3       3       3       333
# 55          2    5593.42       2       1       2       212
# 58          3    1292.08       1       1       1       111
# 63          2    6516.81       3       1       2       312
# 65          4    7468.47       2       2       2       222
# 66          8   51650.13       5       3       5       535
# 67          4    2218.07       1       2       1       121
# 70          5    6265.53       1       2       2       122
# 73          1    1863.86       1       1       1       111
# 74          3    6879.02       1       1       2       112
# 75         11   11575.84       2       4       3       243
# 76          6    7080.02       1       2       2       122
# 77          6    6648.38       2       2       2       222
# 78          6    8009.65       2       3       3       233
# 82          8   14838.25       2       3       3       233
# 84          2    3686.58       1       1       1       111
# 85          2    8031.62       2       1       3       213
# 87          1   10432.06       2       1       3       213
# 88          2    3213.61       3       1       1       311
# 89          4    4900.12       1       2       2       122
# 90         12    4844.34       4       4       2       442
# 98          1   10113.80       2       1       3       213
# 99          3    6824.60       3       1       2       312
#
#                segment  assigned_sales_id
# 0             Champion        SAL_RUH_001
# 3             Champion        SAL_RUH_001
# 6   Potential Loyalist        SAL_RUH_001
# 9             Champion        SAL_RUH_001
# 12            Champion        SAL_RUH_001
# 15            Champion        SAL_RUH_001
# 18            Champion        SAL_RUH_001
# 23  Potential Loyalist        SAL_RUH_001
# 25  Potential Loyalist        SAL_RUH_001
# 26      Need Attention        SAL_RUH_001
# 27            Champion        SAL_RUH_001
# 28            Champion        SAL_RUH_001
# 33         Hibernating        SAL_RUH_001
# 34               Loyal        SAL_RUH_001
# 35             At Risk        SAL_RUH_001
# 36         Hibernating        SAL_RUH_001
# 37      Need Attention        SAL_RUH_001
# 38         Hibernating        SAL_RUH_001
# 41               Loyal        SAL_RUH_001
# 43      Need Attention        SAL_RUH_001
# 44      Need Attention        SAL_RUH_001
# 45         Hibernating        SAL_RUH_001
# 47            Champion        SAL_RUH_001
# 51         Hibernating        SAL_RUH_001
# 52      Need Attention        SAL_RUH_001
# 53      Need Attention        SAL_RUH_001
# 54      Need Attention        SAL_RUH_001
# 55         Hibernating        SAL_RUH_001
# 58         Hibernating        SAL_RUH_001
# 63      Need Attention        SAL_RUH_001
# 65         Hibernating        SAL_RUH_001
# 66  Potential Loyalist        SAL_RUH_001
# 67         Hibernating        SAL_RUH_001
# 70         Hibernating        SAL_RUH_001
# 73         Hibernating        SAL_RUH_001
# 74         Hibernating        SAL_RUH_001
# 75               Loyal        SAL_RUH_001
# 76         Hibernating        SAL_RUH_001
# 77         Hibernating        SAL_RUH_001
# 78             At Risk        SAL_RUH_001
# 82             At Risk        SAL_RUH_001
# 84         Hibernating        SAL_RUH_001
# 85      Need Attention        SAL_RUH_001
# 87      Need Attention        SAL_RUH_001
# 88      Need Attention        SAL_RUH_001
# 89         Hibernating        SAL_RUH_001
# 90      Need Attention        SAL_RUH_001
# 98      Need Attention        SAL_RUH_001
# 99      Need Attention        SAL_RUH_001
#
# [49 rows x 27 columns]), 'SAL_RUH_002': SalespersonScheduleResult(sales_id='SAL_RUH_002', territory_id='TER_RUH', detailed_schedule=   schedule_date     sales_id territory_id   customer_id  \
# 0     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0044
# 1     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0073
# 2     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 3     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 4     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 5     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 6     2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0033
# 7     2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 8     2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0072
# 9     2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 10    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0073
# 11    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 12    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 13    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 14    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0073
# 15    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 16    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 17    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 18    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 19    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 20    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 21    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0003
# 22    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 23    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 24    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0032
# 25    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0033
# 26    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 27    2026-06-23  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 28    2026-06-23  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 29    2026-06-23  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 30    2026-06-24  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 31    2026-06-24  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 32    2026-06-24  SAL_RUH_002      TER_RUH  CUS_RUH_0073
# 33    2026-06-25  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 34    2026-06-25  SAL_RUH_002      TER_RUH  CUS_RUH_0089
# 35    2026-06-25  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 36    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 37    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 38    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 39    2026-06-28  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 40    2026-06-28  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 41    2026-06-28  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 42    2026-06-29  SAL_RUH_002      TER_RUH  CUS_RUH_0032
# 43    2026-06-29  SAL_RUH_002      TER_RUH  CUS_RUH_0033
# 44    2026-06-29  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 45    2026-06-30  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 46    2026-06-30  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 47    2026-06-30  SAL_RUH_002      TER_RUH  CUS_RUH_0091
#
#                               shop_name         locality    gps_lat  \
# 0        Al Nada Fresh Catering Kitchen        Al Yasmin  24.821430
# 1                 Al Rawabi Mini Market        Al Yasmin  24.818397
# 2                 Al Riyadh Supermarket        Al Yasmin  24.843331
# 3                         Hittin Market           Hittin  24.765952
# 4              Al Shammari Trading Cafe        Al Yasmin  24.826697
# 5                  Al Noor Coffee House        Al Yasmin  24.851244
# 6        Al Dossari Trading Mini Market        Al Yasmin  24.830435
# 7        Al Mutairi Trading Supermarket            Olaya  24.711201
# 8                     Al Mutairi Baqala        Al Yasmin  24.834435
# 9           Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 10                Al Rawabi Mini Market        Al Yasmin  24.818397
# 11                Al Riyadh Supermarket        Al Yasmin  24.843331
# 12                   Al Baraka Butchery           Hittin  24.766215
# 13          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 14                Al Rawabi Mini Market        Al Yasmin  24.818397
# 15                        Hittin Market           Hittin  24.765952
# 16          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 17                 Al Noor Coffee House        Al Yasmin  24.851244
# 18                   Al Baraka Butchery           Hittin  24.766215
# 19               Al Malki Hotel Kitchen            Olaya  24.703445
# 20         Al Malki Trading Mini Market           Hittin  24.741617
# 21          Al Qassim Al Yasmin Grocery        Al Yasmin  24.844884
# 22             Al Shammari Trading Cafe        Al Yasmin  24.826697
# 23                 Al Noor Coffee House        Al Yasmin  24.851244
# 24  Al Zahrani Trading Catering Kitchen  Al Sulaymaniyah  24.697510
# 25       Al Dossari Trading Mini Market        Al Yasmin  24.830435
# 26       Al Mutairi Trading Supermarket            Olaya  24.711201
# 27                   Al Baraka Butchery           Hittin  24.766215
# 28                Al Riyadh Supermarket        Al Yasmin  24.843331
# 29         Al Malki Trading Mini Market           Hittin  24.741617
# 30                        Hittin Market           Hittin  24.765952
# 31          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 32                Al Rawabi Mini Market        Al Yasmin  24.818397
# 33                        Hittin Market           Hittin  24.765952
# 34             Al Nakheel Corner Market        Al Yasmin  24.824256
# 35         Al Malki Trading Mini Market           Hittin  24.741617
# 36                   Al Baraka Butchery           Hittin  24.766215
# 37               Al Malki Hotel Kitchen            Olaya  24.703445
# 38         Al Malki Trading Mini Market           Hittin  24.741617
# 39             Al Shammari Trading Cafe        Al Yasmin  24.826697
# 40               Al Malki Hotel Kitchen            Olaya  24.703445
# 41                 Al Noor Coffee House        Al Yasmin  24.851244
# 42  Al Zahrani Trading Catering Kitchen  Al Sulaymaniyah  24.697510
# 43       Al Dossari Trading Mini Market        Al Yasmin  24.830435
# 44       Al Mutairi Trading Supermarket            Olaya  24.711201
# 45       Al Mutairi Trading Supermarket            Olaya  24.711201
# 46               Al Malki Hotel Kitchen            Olaya  24.703445
# 47                Al Riyadh Supermarket        Al Yasmin  24.843331
#
#       gps_lng         segment lifecycle_state  cold_truck_required  \
# 0   46.610959  Need Attention          Active                False
# 1   46.627262        Champion          Active                False
# 2   46.612384        Champion          Active                False
# 3   46.577897        Champion          Active                 True
# 4   46.649614           Loyal          Active                False
# 5   46.638066        Champion          Active                False
# 6   46.633439           Loyal         At Risk                False
# 7   46.675347        Champion             New                 True
# 8   46.626288         At Risk          Active                False
# 9   46.644290        Champion          Active                False
# 10  46.627262        Champion          Active                False
# 11  46.612384        Champion          Active                False
# 12  46.605835        Champion          Active                 True
# 13  46.644290        Champion          Active                False
# 14  46.627262        Champion          Active                False
# 15  46.577897        Champion          Active                 True
# 16  46.644290        Champion          Active                False
# 17  46.638066        Champion          Active                False
# 18  46.605835        Champion          Active                 True
# 19  46.683025        Champion          Active                 True
# 20  46.600318        Champion          Active                False
# 21  46.639722  Need Attention         At Risk                False
# 22  46.649614           Loyal          Active                False
# 23  46.638066        Champion          Active                False
# 24  46.706340           Loyal         At Risk                 True
# 25  46.633439           Loyal         At Risk                False
# 26  46.675347        Champion             New                 True
# 27  46.605835        Champion          Active                 True
# 28  46.612384        Champion          Active                False
# 29  46.600318        Champion          Active                False
# 30  46.577897        Champion          Active                 True
# 31  46.644290        Champion          Active                False
# 32  46.627262        Champion          Active                False
# 33  46.577897        Champion          Active                 True
# 34  46.614717  Need Attention          Active                False
# 35  46.600318        Champion          Active                False
# 36  46.605835        Champion          Active                 True
# 37  46.683025        Champion          Active                 True
# 38  46.600318        Champion          Active                False
# 39  46.649614           Loyal          Active                False
# 40  46.683025        Champion          Active                 True
# 41  46.638066        Champion          Active                False
# 42  46.706340           Loyal         At Risk                 True
# 43  46.633439           Loyal         At Risk                False
# 44  46.675347        Champion             New                 True
# 45  46.675347        Champion             New                 True
# 46  46.683025        Champion          Active                 True
# 47  46.612384        Champion          Active                False
#
#     estimated_visit_minutes  estimated_travel_minutes
# 0                        22                       129
# 1                        22                       124
# 2                        22                       136
# 3                        22                       121
# 4                        22                       122
# 5                        22                       133
# 6                        22                       127
# 7                        22                        78
# 8                        22                       130
# 9                        22                       126
# 10                       22                       124
# 11                       22                       136
# 12                       22                       113
# 13                       22                       126
# 14                       22                       124
# 15                       22                       121
# 16                       22                       126
# 17                       22                       133
# 18                       22                       113
# 19                       22                        74
# 20                       22                       108
# 21                       22                       130
# 22                       22                       122
# 23                       22                       133
# 24                       22                        66
# 25                       22                       127
# 26                       22                        78
# 27                       22                       113
# 28                       22                       136
# 29                       22                       108
# 30                       22                       121
# 31                       22                       126
# 32                       22                       124
# 33                       22                       121
# 34                       22                       129
# 35                       22                       108
# 36                       22                       113
# 37                       22                        74
# 38                       22                       108
# 39                       22                       122
# 40                       22                        74
# 41                       22                       133
# 42                       22                        66
# 43                       22                       127
# 44                       22                        78
# 45                       22                        78
# 46                       22                        74
# 47                       22                       136  , daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_RUH_002      TER_RUH
# 1     2026-06-14  SAL_RUH_002      TER_RUH
# 2     2026-06-15  SAL_RUH_002      TER_RUH
# 3     2026-06-16  SAL_RUH_002      TER_RUH
# 4     2026-06-17  SAL_RUH_002      TER_RUH
# 5     2026-06-18  SAL_RUH_002      TER_RUH
# 6     2026-06-20  SAL_RUH_002      TER_RUH
# 7     2026-06-21  SAL_RUH_002      TER_RUH
# 8     2026-06-22  SAL_RUH_002      TER_RUH
# 9     2026-06-23  SAL_RUH_002      TER_RUH
# 10    2026-06-24  SAL_RUH_002      TER_RUH
# 11    2026-06-25  SAL_RUH_002      TER_RUH
# 12    2026-06-27  SAL_RUH_002      TER_RUH
# 13    2026-06-28  SAL_RUH_002      TER_RUH
# 14    2026-06-29  SAL_RUH_002      TER_RUH
# 15    2026-06-30  SAL_RUH_002      TER_RUH
#
#                                  customer_list  customer_count  \
# 0   [CUS_RUH_0073, CUS_RUH_0044, CUS_RUH_0091]               3
# 1   [CUS_RUH_0013, CUS_RUH_0025, CUS_RUH_0079]               3
# 2   [CUS_RUH_0038, CUS_RUH_0033, CUS_RUH_0072]               3
# 3   [CUS_RUH_0073, CUS_RUH_0071, CUS_RUH_0091]               3
# 4   [CUS_RUH_0052, CUS_RUH_0073, CUS_RUH_0071]               3
# 5   [CUS_RUH_0013, CUS_RUH_0071, CUS_RUH_0079]               3
# 6   [CUS_RUH_0077, CUS_RUH_0096, CUS_RUH_0052]               3
# 7   [CUS_RUH_0025, CUS_RUH_0003, CUS_RUH_0079]               3
# 8   [CUS_RUH_0032, CUS_RUH_0038, CUS_RUH_0033]               3
# 9   [CUS_RUH_0096, CUS_RUH_0052, CUS_RUH_0091]               3
# 10  [CUS_RUH_0013, CUS_RUH_0073, CUS_RUH_0071]               3
# 11  [CUS_RUH_0096, CUS_RUH_0013, CUS_RUH_0089]               3
# 12  [CUS_RUH_0077, CUS_RUH_0096, CUS_RUH_0052]               3
# 13  [CUS_RUH_0077, CUS_RUH_0025, CUS_RUH_0079]               3
# 14  [CUS_RUH_0032, CUS_RUH_0038, CUS_RUH_0033]               3
# 15  [CUS_RUH_0077, CUS_RUH_0038, CUS_RUH_0091]               3
#
#                                           route_order  total_visit_min  \
# 0   [Al Rawabi Mini Market, Al Nada Fresh Catering...               66
# 1   [Hittin Market, Al Shammari Trading Cafe, Al N...               66
# 2   [Al Mutairi Trading Supermarket, Al Dossari Tr...               66
# 3   [Al Rawabi Mini Market, Al Riyadh Fresh Mini M...               66
# 4   [Al Baraka Butchery, Al Rawabi Mini Market, Al...               66
# 5   [Hittin Market, Al Riyadh Fresh Mini Market, A...               66
# 6   [Al Malki Hotel Kitchen, Al Malki Trading Mini...               66
# 7   [Al Shammari Trading Cafe, Al Qassim Al Yasmin...               66
# 8   [Al Zahrani Trading Catering Kitchen, Al Mutai...               66
# 9   [Al Malki Trading Mini Market, Al Baraka Butch...               66
# 10  [Hittin Market, Al Rawabi Mini Market, Al Riya...               66
# 11  [Al Malki Trading Mini Market, Hittin Market, ...               66
# 12  [Al Malki Hotel Kitchen, Al Malki Trading Mini...               66
# 13  [Al Malki Hotel Kitchen, Al Shammari Trading C...               66
# 14  [Al Zahrani Trading Catering Kitchen, Al Mutai...               66
# 15  [Al Malki Hotel Kitchen, Al Mutairi Trading Su...               66
#
#     total_travel_min
# 0                389
# 1                376
# 2                335
# 3                386
# 4                363
# 5                380
# 6                295
# 7                385
# 8                271
# 9                357
# 10               371
# 11               358
# 12               295
# 13               329
# 14               271
# 15               288  , assigned_customers=     customer_id                            shop_name    gps_lat    gps_lng  \
# 1   CUS_RUH_0013                        Hittin Market  24.765952  46.577897
# 4   CUS_RUH_0032  Al Zahrani Trading Catering Kitchen  24.697510  46.706340
# 7   CUS_RUH_0038       Al Mutairi Trading Supermarket  24.711201  46.675347
# 10  CUS_RUH_0052                   Al Baraka Butchery  24.766215  46.605835
# 13  CUS_RUH_0077               Al Malki Hotel Kitchen  24.703445  46.683025
# 16  CUS_RUH_0091                Al Riyadh Supermarket  24.843331  46.612384
# 19  CUS_RUH_0096         Al Malki Trading Mini Market  24.741617  46.600318
# 72  CUS_RUH_0003          Al Qassim Al Yasmin Grocery  24.844884  46.639722
# 79  CUS_RUH_0025             Al Shammari Trading Cafe  24.826697  46.649614
# 81  CUS_RUH_0033       Al Dossari Trading Mini Market  24.830435  46.633439
# 83  CUS_RUH_0044       Al Nada Fresh Catering Kitchen  24.821430  46.610959
# 91  CUS_RUH_0071          Al Riyadh Fresh Mini Market  24.833529  46.644290
# 92  CUS_RUH_0072                    Al Mutairi Baqala  24.834435  46.626288
# 93  CUS_RUH_0073                Al Rawabi Mini Market  24.818397  46.627262
# 94  CUS_RUH_0079                 Al Noor Coffee House  24.851244  46.638066
# 96  CUS_RUH_0086           Al Jazeera Banquet Kitchen  24.821647  46.645920
# 97  CUS_RUH_0089             Al Nakheel Corner Market  24.824256  46.614717
#
#            locality territory_id  customer_rating  review_rating  \
# 1            Hittin      TER_RUH                4            3.3
# 4   Al Sulaymaniyah      TER_RUH                5            3.2
# 7             Olaya      TER_RUH                4            5.0
# 10           Hittin      TER_RUH                5            3.6
# 13            Olaya      TER_RUH                4            3.6
# 16        Al Yasmin      TER_RUH                5            4.6
# ...
#
#     estimated_travel_minutes
# 0                         59
# 1                         64
# 2                         70
# 3                         66
# 4                         68
# ..                       ...
# 70                        59
# 71                        64
# 72                        65
# 73                        56
# 74                        68
#
# [75 rows x 13 columns], daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_DMM_003      TER_DMM
# 1     2026-06-14  SAL_DMM_003      TER_DMM
# 2     2026-06-15  SAL_DMM_003      TER_DMM
# 3     2026-06-16  SAL_DMM_003      TER_DMM
# 4     2026-06-17  SAL_DMM_003      TER_DMM
# 5     2026-06-18  SAL_DMM_003      TER_DMM
# 6     2026-06-21  SAL_DMM_003      TER_DMM
# 7     2026-06-22  SAL_DMM_003      TER_DMM
# 8     2026-06-23  SAL_DMM_003      TER_DMM
# 9     2026-06-24  SAL_DMM_003      TER_DMM
# 10    2026-06-25  SAL_DMM_003      TER_DMM
# 11    2026-06-27  SAL_DMM_003      TER_DMM
# 12    2026-06-28  SAL_DMM_003      TER_DMM
# 13    2026-06-29  SAL_DMM_003      TER_DMM
# 14    2026-06-30  SAL_DMM_003      TER_DMM
#
#                                         customer_list  customer_count  \
# 0   [CUS_DMM_0020, CUS_DMM_0052, CUS_DMM_0025, CUS...               5
# 1   [CUS_DMM_0044, CUS_DMM_0093, CUS_DMM_0078, CUS...               5
# 2   [CUS_DMM_0081, CUS_DMM_0069, CUS_DMM_0060, CUS...               5
# 3   [CUS_DMM_0020, CUS_DMM_0025, CUS_DMM_0019, CUS...               5
# 4   [CUS_DMM_0058, CUS_DMM_0010, CUS_DMM_0096, CUS...               5
# 5   [CUS_DMM_0088, CUS_DMM_0052, CUS_DMM_0008, CUS...               5
# 6   [CUS_DMM_0010, CUS_DMM_0082, CUS_DMM_0021, CUS...               5
# 7   [CUS_DMM_0088, CUS_DMM_0058, CUS_DMM_0028, CUS...               5
# 8   [CUS_DMM_0020, CUS_DMM_0025, CUS_DMM_0055, CUS...               5
# 9   [CUS_DMM_0058, CUS_DMM_0010, CUS_DMM_0052, CUS...               5
# 10  [CUS_DMM_0048, CUS_DMM_0077, CUS_DMM_0035, CUS...               5
# 11  [CUS_DMM_0088, CUS_DMM_0010, CUS_DMM_0093, CUS...               5
# 12  [CUS_DMM_0044, CUS_DMM_0092, CUS_DMM_0022, CUS...               5
# 13  [CUS_DMM_0081, CUS_DMM_0052, CUS_DMM_0038, CUS...               5
# 14  [CUS_DMM_0058, CUS_DMM_0020, CUS_DMM_0025, CUS...               5
#
#                                           route_order  total_visit_min  \
# 0   [Al Tazaj Catering Kitchen, Al Manar Fresh Col...              110
# 1   [Al Madina Fresh Corner Market, Al Othman Trad...              110
# 2   [Al Qahtani Trading Bakery, Al Mutairi Trading...              110
# 3   [Al Tazaj Catering Kitchen, Al Rawabi Fresh Ki...              110
# 4   [Al Rashid Hospitality Supplies, Al Malki Trad...              110
# 5   [Al Malki Trading Sweets & Bakery, Al Manar Fr...              110
# 6   [Al Malki Trading Chilled Foods, Al Badiyah Gr...              110
# 7   [Al Malki Trading Sweets & Bakery, Al Rashid H...              110
# 8   [Al Tazaj Catering Kitchen, Al Rawabi Fresh Ki...              110
# 9   [Al Rashid Hospitality Supplies, Al Malki Trad...              110
# 10  [Al Madina Hyper Mini, Al Khaleej Fresh Mini M...              110
# 11  [Al Malki Trading Sweets & Bakery, Al Malki Tr...              110
# 12  [Al Madina Fresh Corner Market, Al Zahrani Tra...              110
# 13  [Al Qahtani Trading Bakery, Al Manar Fresh Col...              110
# 14  [Al Rashid Hospitality Supplies, Al Tazaj Cate...              110
#
#     total_travel_min
# 0                327
# 1                328
# 2                330
# 3                349
# 4                303
# 5                318
# 6                315
# 7                305
# 8                347
# 9                308
# 10               350
# 11               319
# 12               323
# 13               324
# 14               312  , assigned_customers=     customer_id                           shop_name    gps_lat    gps_lng  \
# 2   CUS_DMM_0010      Al Malki Trading Chilled Foods  26.400683  50.059401
# 5   CUS_DMM_0040                Al Saleh Supermarket  26.449793  50.091627
# 8   CUS_DMM_0052           Al Manar Fresh Cold Store  26.413965  50.046764
# 11  CUS_DMM_0058      Al Rashid Hospitality Supplies  26.395766  50.066651
# 14  CUS_DMM_0077        Al Khaleej Fresh Mini Market  26.443368  50.092656
# 17  CUS_DMM_0093            Al Othman Trading Baqala  26.422371  50.081414
# 21  CUS_DMM_0004                 Al Malki Cold Store  26.450547  50.051529
# 23  CUS_DMM_0008      Al Jazeera Fresh Chilled Foods  26.439009  50.066969
# 27  CUS_DMM_0019       Al Tazaj Hospitality Supplies  26.431079  50.059445
# 30  CUS_DMM_0025             Al Rawabi Fresh Kitchen  26.424341  50.073929
# 33  CUS_DMM_0035            Al Jazeera Chilled Foods  26.440168  50.078485
# 35  CUS_DMM_0038                  Al Nuzha Meat Shop  26.432611  50.036447
# 37  CUS_DMM_0044       Al Madina Fresh Corner Market  26.419435  50.081063
# 38  CUS_DMM_0045                    Al Rashid Bakery  26.452697  50.074785
# 39  CUS_DMM_0048                Al Madina Hyper Mini  26.433690  50.088341
# 42  CUS_DMM_0055  Al Dana Al Badiyah Banquet Kitchen  26.430930  50.057492
# 43  CUS_DMM_0060             Al Baraka Fresh Grocery  26.425413  50.077664
# 44  CUS_DMM_0061              Al Manar Chilled Foods  26.435701  50.026507
# 46  CUS_DMM_0065              Al Zahrani Supermarket  26.431258  50.062544
# 48  CUS_DMM_0075                  Al Zahrani Kitchen  26.459588  50.038737
# 49  CUS_DMM_0078           Al Riyadh Banquet Kitchen  26.437755  50.083570
# 52  CUS_DMM_0089      Al Qahtani Trading Supermarket  26.426799  50.038424
# 54  CUS_DMM_0092       Al Zahrani Trading Cold Store  26.419969  50.078183
# 57  CUS_DMM_0096                   Al Manar Butchery  26.422896  50.066042
# 65  CUS_DMM_0020           Al Tazaj Catering Kitchen  26.401828  50.061190
# 66  CUS_DMM_0021  Al Dossari Trading Banquet Kitchen  26.395640  50.051825
# 67  CUS_DMM_0022       Al Saleh Trading Coffee House  26.422080  50.069636
# 68  CUS_DMM_0026            Al Mutairi Corner Market  26.393341  50.044737
# 70  CUS_DMM_0028                     Al Safa Grocery  26.389385  50.052105
# 73  CUS_DMM_0033                      Al Othman Oven  26.405773  50.042970
# 86  CUS_DMM_0069      Al Mutairi Trading Supermarket  26.423307  50.074712
# 90  CUS_DMM_0076                      Al Dana Bakery  26.418467  50.078559
# 91  CUS_DMM_0081           Al Qahtani Trading Bakery  26.401543  50.067184
# 92  CUS_DMM_0082                  Al Badiyah Grocery  26.406406  50.060793
# 96  CUS_DMM_0088    Al Malki Trading Sweets & Bakery  26.385031  50.078156
#
#          locality territory_id  customer_rating  review_rating  \
# 2      Al Badiyah      TER_DMM                4            4.6
# 5    Al Mazruiyah      TER_DMM                4            4.0
# 8      Al Badiyah      TER_DMM                4            5.0
# 11     Al Badiyah      TER_DMM                3            4.5
# 14   Al Mazruiyah      TER_DMM                5            3.3
# 17  Al Faisaliyah      TER_DMM                5            4.0
# 21       Al Nuzha      TER_DMM                4            4.0
# 23       Al Nuzha      TER_DMM                2            4.7
# 27     Al Badiyah      TER_DMM                3            4.0
# 30  Al Faisaliyah      TER_DMM                3            3.2
# 33   Al Mazruiyah      TER_DMM                4            3.1
# 35       Al Nuzha      TER_DMM                5            4.2
# 37  Al Faisaliyah      TER_DMM                4            3.5
# 38   Al Mazruiyah      TER_DMM                2            4.6
# 39   Al Mazruiyah      TER_DMM                4            4.0
# 42     Al Badiyah      TER_DMM                3            4.6
# 43  Al Faisaliyah      TER_DMM                3            4.3
# 44       Al Nuzha      TER_DMM                3            4.2
# 46  Al Faisaliyah      TER_DMM                4            3.4
# 48       Al Nuzha      TER_DMM                3            3.8
# 49   Al Mazruiyah      TER_DMM                3            3.6
# 52       Al Nuzha      TER_DMM                5            4.2
# 54  Al Faisaliyah      TER_DMM                5            5.0
# 57     Al Badiyah      TER_DMM                3            3.8
# 65     Al Badiyah      TER_DMM                5            3.9
# 66     Al Badiyah      TER_DMM                1            4.0
# 67  Al Faisaliyah      TER_DMM                1            4.1
# 68     Al Badiyah      TER_DMM                3            5.0
# 70     Al Badiyah      TER_DMM                2            4.3
# 73     Al Badiyah      TER_DMM                5            4.5
# 86  Al Faisaliyah      TER_DMM                2            4.1
# 90     Al Badiyah      TER_DMM                4            3.7
# 91     Al Badiyah      TER_DMM                5            3.4
# 92     Al Badiyah      TER_DMM                2            4.3
# 96     Al Badiyah      TER_DMM                4            5.0
#
#        shop_category  cold_truck_required  ... preferred_order_window recency  \
# 2         Cold Store                 True  ...                 Midday      16
# 5        Supermarket                 True  ...                Morning      16
# 8         Cold Store                 True  ...                 Midday       4
# 11     Hotel Kitchen                False  ...              Afternoon      17
# 14       Mini Market                False  ...                Morning      11
# 17           Grocery                False  ...              Afternoon      20
# 21        Cold Store                 True  ...                Morning      39
# 23        Cold Store                 True  ...                Morning      20
# 27     Hotel Kitchen                 True  ...                Morning      26
# 30        Restaurant                 True  ...              Afternoon      10
# 33        Cold Store                 True  ...                 Midday      59
# 35          Butchery                 True  ...              Afternoon      23
# 37       Mini Market                 True  ...                Morning       6
# 38            Bakery                 True  ...              Afternoon      62
# 39       Supermarket                 True  ...              Afternoon      14
# 42  Catering Kitchen                 True  ...                 Midday      39
# 43           Grocery                 True  ...                Morning      20
# 44        Cold Store                 True  ...                 Midday      31
# 46       Supermarket                 True  ...              Afternoon      88
# 48        Restaurant                 True  ...              Afternoon      41
# 49  Catering Kitchen                 True  ...              Afternoon      37
# 52       Supermarket                 True  ...              Afternoon      42
# 54        Cold Store                 True  ...              Afternoon       7
# 57          Butchery                 True  ...              Afternoon      69
# 65  Catering Kitchen                False  ...                 Midday      18
# 66  Catering Kitchen                False  ...                Morning       8
# 67              Cafe                False  ...                Morning       6
# 68       Mini Market                False  ...                Morning      87
# 70           Grocery                False  ...              Afternoon      65
# 73            Bakery                False  ...              Afternoon     142
# 86       Supermarket                False  ...                Morning       2
# 90            Bakery                False  ...                Morning      79
# 91            Bakery                False  ...                 Midday       2
# 92           Grocery                False  ...                 Midday      67
# 96            Bakery                False  ...              Afternoon      28
#
#     frequency   monetary r_score f_score m_score rfm_score  \
# 2          37  150155.46       4       5       5       455
# 5          45   30511.53       4       5       4       454
# 8          31  146666.32       5       5       5       555
# 11         41  178871.65       4       5       5       455
# 14         10   49554.93       4       4       5       445
# 17         44  152079.19       4       5       5       455
# 21          3   10491.41       3       2       3       323
# 23         10    9302.05       4       3       3       433
# 27          2    5295.00       4       1       2       412
# 30         11   34425.62       5       4       4       544
# 33          5    6326.93       2       2       2       222
# 35          3    2731.18       4       2       1       421
# 37          4    2267.17       5       2       1       521
# 38          6    1261.45       2       3       1       231
# 39         17   40852.78       4       4       4       444
# 42          4    4411.33       3       2       2       322
# 43          5   11221.88       4       2       3       423
# 44          6    5869.07       3       3       2       332
# 46          2    6192.90       1       1       2       112
# 48         10   53736.73       3       4       5       345
# 49         15   52477.52       3       4       5       345
# 52         11    8200.46       3       4       3       343
# 54          2     727.64       5       1       1       511
# 57         10    7146.21       2       4       2       242
# 65         13   39260.34       4       4       4       444
# 66         11    5835.09       5       4       2       542
# 67          1    3572.94       5       1       1       511
# 68          2    6062.12       1       1       2       112
# 70          3    7564.33       2       2       2       222
# 73          1    2246.77       1       1       1       111
# 86          3    1864.25       5       2       1       521
# 90         10    2015.65       1       4       1       141
# 91          3    2277.69       5       2       1       521
# 92          8   13376.11       2       3       3       233
# 96         25   40318.39       3       5       4       354
#
#                segment  assigned_sales_id
# 2             Champion        SAL_DMM_003
# 5             Champion        SAL_DMM_003
# 8             Champion        SAL_DMM_003
# 11            Champion        SAL_DMM_003
# 14            Champion        SAL_DMM_003
# 17            Champion        SAL_DMM_003
# 21      Need Attention        SAL_DMM_003
# 23  Potential Loyalist        SAL_DMM_003
# 27      Need Attention        SAL_DMM_003
# 30            Champion        SAL_DMM_003
# 33         Hibernating        SAL_DMM_003
# 35  Potential Loyalist        SAL_DMM_003
# 37  Potential Loyalist        SAL_DMM_003
# 38             At Risk        SAL_DMM_003
# 39            Champion        SAL_DMM_003
# 42      Need Attention        SAL_DMM_003
# 43  Potential Loyalist        SAL_DMM_003
# 44      Need Attention        SAL_DMM_003
# 46         Hibernating        SAL_DMM_003
# 48               Loyal        SAL_DMM_003
# 49               Loyal        SAL_DMM_003
# 52               Loyal        SAL_DMM_003
# 54      Need Attention        SAL_DMM_003
# 57             At Risk        SAL_DMM_003
# 65            Champion        SAL_DMM_003
# 66      Need Attention        SAL_DMM_003
# 67      Need Attention        SAL_DMM_003
# 68         Hibernating        SAL_DMM_003
# 70         Hibernating        SAL_DMM_003
# 73         Hibernating        SAL_DMM_003
# 86  Potential Loyalist        SAL_DMM_003
# 90             At Risk        SAL_DMM_003
# 91  Potential Loyalist        SAL_DMM_003
# 92             At Risk        SAL_DMM_003
# 96               Loyal        SAL_DMM_003
#
# [35 rows x 27 columns])}, territory_warehouses={'TER_RUH': (24.579, 46.8237), 'TER_JED': (21.3429, 39.2357), 'TER_DMM': (26.2926, 50.1629)})

# %%
import pandas as pd

# Define the output file name
excel_file_path = "monthly_plan.xlsx"

with pd.ExcelWriter(excel_file_path, engine="openpyxl") as writer:
    # 1. Save the main aggregated dataframes to their own sheets
    result.detailed_schedule.to_excel(
        writer, sheet_name="Detailed Schedule", index=False
    )
    result.daily_schedule.to_excel(writer, sheet_name="Daily Schedule", index=False)

    # 2. Loop through the salesperson dictionary and write each to a sheet
    for name, sp_result in result.salesperson_results.items():
        # Excel sheet names cannot exceed 31 characters
        safe_sheet_name = f"SP_{name}"

        # Check if the salesperson result object itself has dataframes to unpack
        # If it is a dictionary, use: sp_result_dict = sp_result
        # If it is another dataclass, convert it to a dict to read its attributes
        if hasattr(sp_result, "__dataclass_fields__"):
            from dataclasses import asdict

            sp_data = asdict(sp_result)
        elif isinstance(sp_result, dict):
            sp_data = sp_result
        else:
            # Fallback: tries to extract internal attributes if it's a custom class
            sp_data = vars(sp_result)

        # Look for any pandas DataFrames inside the salesperson's data to save
        for key, value in sp_data.items():
            if isinstance(value, pd.DataFrame):
                # Creates a unique sheet name like "SP_John_detailed"
                sub_sheet_name = f"SP_{name}_{key}"
                value.to_excel(writer, sheet_name=sub_sheet_name, index=False)

print(f"Successfully saved results to {excel_file_path}")
# Out:
# d:\Data Science\Basamh\JP\journey-planner\.venv\Lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
# Successfully saved results to monthly_plan.xlsx

# %%
from saudi_multi_salesperson_scheduler import build_route_map_for_salesperson, build_territory_day_map
# m = build_route_map_for_salesperson(
#     daily_schedule    = result.daily_schedule,
#     detailed_schedule = result.detailed_schedule,
#     sales_id          = "SAL_DMM_001",
#     schedule_date     = "2026-07-02",
# )
# display(m)

# m = build_route_map_for_salesperson(
#     daily_schedule    = result.daily_schedule,
#     detailed_schedule = result.detailed_schedule,
#     sales_id          = "SAL_DMM_002",
#     schedule_date     = "2026-07-02",
# )
# display(m)

# m = build_route_map_for_salesperson(
#     daily_schedule    = result.daily_schedule,
#     detailed_schedule = result.detailed_schedule,
#     sales_id          = "SAL_DMM_003",
#     schedule_date     = "2026-07-02",
# )
# display(m)

wh = result.territory_warehouses["TER_DMM"]
m = build_route_map_for_salesperson(
    daily_schedule    = result.daily_schedule,
    detailed_schedule = result.detailed_schedule,
    sales_id          = "SAL_DMM_001",
    schedule_date     = "2026-06-16",
    warehouse_lat     = wh[0],
    warehouse_lng     = wh[1],
)
display(m)

# ALL salespeople in a territory on one map
m = build_territory_day_map(
    result        = result,
    territory_id  = "TER_DMM",
    schedule_date = "2026-06-16",
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc1d284ee8e6f8e58115a3a4802cc57a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;top:10px;left:60px;z-index:1000;
#                 background:white;padding:8px 12px;border-radius:6px;
#                 border:1px solid #ccc;font-family:sans-serif;&quot;&gt;
#         &lt;b&gt;SAL_RUH_001&lt;/b&gt; — 21 Jun 2026 &amp;nbsp;|&amp;nbsp; 5 stops
#     &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc1d284ee8e6f8e58115a3a4802cc57a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc1d284ee8e6f8e58115a3a4802cc57a = L.map(
#                 &quot;map_bc1d284ee8e6f8e58115a3a4802cc57a&quot;,
#                 {
#                     center: [24.7064518, 46.6868808],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_279b2e5b0cb2768d0df4cdf6afc1a28d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_279b2e5b0cb2768d0df4cdf6afc1a28d.addTo(map_bc1d284ee8e6f8e58115a3a4802cc57a);
#
#
#             var marker_2e210307bb5ea2fe95593f1a09207eee = L.marker(
#                 [24.579, 46.8237],
#                 {
# }
#             ).addTo(map_bc1d284ee8e6f8e58115a3a4802cc57a);
#
#
#             var icon_45d7c52e30b73f4acb254df72be2d6b7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5c8029d9b53ccfc0ddd1d61268c0dff6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cd1b6c11fdd7d4f1990b8f202325cdc = $(`&lt;div id=&quot;html_8cd1b6c11fdd7d4f1990b8f202325cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Warehouse&lt;/b&gt;&lt;br&gt;Start and end of route&lt;/div&gt;`)[0];
#                 popup_5c8029d9b53ccfc0ddd1d61268c0dff6.setContent(html_8cd1b6c11fdd7d4f1990b8f202325cdc);
#
#
#
#         marker_2e210307bb5ea2fe95593f1a09207eee.bindPopup(popup_5c8029d9b53ccfc0ddd1d61268c0dff6)
#         ;
#
#
#
#
#             marker_2e210307bb5ea2fe95593f1a09207eee.bindTooltip(
#                 `&lt;div&gt;
#                      🏭 Warehouse (start / end)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_2e210307bb5ea2fe95593f1a09207eee.setIcon(icon_45d7c52e30b73f4acb254df72be2d6b7);
#
#
#             var marker_19b77a798f7e44a6391ccd2a74c34d6b = L.marker(
#                 [24.666298, 46.731369],
#                 {
# }
#             ).addTo(map_bc1d284ee8e6f8e58115a3a4802cc57a);
#
#
#             var div_icon_cd1d1f2c2913ecefc913e17d5201ea5d = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;background:gray;color:white;border-radius:50%;\n                         width:26px;height:26px;text-align:center;line-height:26px;\n                         font-weight:bold;font-size:11px;\&quot;\u003e1\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_19b77a798f7e44a6391ccd2a74c34d6b.bindTooltip(
#                 `&lt;div&gt;
#                      1. Al Ghamdi Trading Corner Market [Hibernating] Al Malaz – Cold: False
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_19b77a798f7e44a6391ccd2a74c34d6b.setIcon(div_icon_cd1d1f2c2913ecefc913e17d5201ea5d);
#
#
#             var marker_54c2d6efe257a8eea85b41447b3e9792 = L.marker(
#                 [24.685095, 46.705745],
#                 {
# }
#             ).addTo(map_bc1d284ee8e6f8e58115a3a4802cc57a);
#
#
#             var div_icon_a6a52b02133ba4fd4555bff2ffa6a1ef = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;background:red;color:white;border-radius:50%;\n                         width:26px;height:26px;text-align:center;line-height:26px;\n                         font-weight:bold;font-size:11px;\&quot;\u003e2\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_54c2d6efe257a8eea85b41447b3e9792.bindTooltip(
#                 `&lt;div&gt;
#                      2. Al Nakheel Grill [Champion] Al Sulaymaniyah – Cold: False
#                  &lt;/div&gt;`,
#                 {
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b882125030953ae462baccc1e900fe2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;top:10px;right:10px;z-index:1000;
#                 background:white;padding:10px 14px;border-radius:8px;
#                 border:1px solid #ccc;font-family:sans-serif;font-size:12px;
#                 min-width:200px;&quot;&gt;
#         &lt;b&gt;TER_RUH&lt;/b&gt; — 21 Jun 2026&lt;br&gt;
#         &lt;ul style=&quot;list-style:none;margin:6px 0 0;padding:0;&quot;&gt;
#             &lt;li&gt;&lt;span style=&quot;background:red;width:14px;height:14px;display:inline-block;border-radius:50%;margin-right:6px;&quot;&gt;&lt;/span&gt;SAL_RUH_001 (5 stops)&lt;/li&gt;&lt;li&gt;&lt;span style=&quot;background:blue;width:14px;height:14px;display:inline-block;border-radius:50%;margin-right:6px;&quot;&gt;&lt;/span&gt;SAL_RUH_002 (3 stops)&lt;/li&gt;&lt;li&gt;&lt;span style=&quot;background:green;width:14px;height:14px;display:inline-block;border-radius:50%;margin-right:6px;&quot;&gt;&lt;/span&gt;SAL_RUH_003 (3 stops)&lt;/li&gt;
#             &lt;li style=&quot;margin-top:6px;&quot;&gt;
#                 &lt;span style=&quot;background:black;width:14px;height:14px;
#                 display:inline-block;border-radius:50%;margin-right:6px;&quot;&gt;&lt;/span&gt;
#                 Warehouse
#             &lt;/li&gt;
#         &lt;/ul&gt;
#     &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b882125030953ae462baccc1e900fe2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b882125030953ae462baccc1e900fe2b = L.map(
#                 &quot;map_b882125030953ae462baccc1e900fe2b&quot;,
#                 {
#                     center: [24.747840727272727, 46.668456090909096],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b3fea90649b67be59aa25f54fd253f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b3fea90649b67be59aa25f54fd253f9.addTo(map_b882125030953ae462baccc1e900fe2b);
#
#
#             var marker_83f37abd906477716b9294e87282fa45 = L.marker(
#                 [24.579, 46.8237],
#                 {
# }
#             ).addTo(map_b882125030953ae462baccc1e900fe2b);
#
#
#             var icon_7a781bddbd9f25eba95b1525d9aa6c3f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a25ce0207e7a5d663f50dd2cb51426d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f7fdf16ba361f795283efeee8a9d756 = $(`&lt;div id=&quot;html_5f7fdf16ba361f795283efeee8a9d756&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Warehouse (TER_RUH)&lt;/b&gt;&lt;br&gt;Start and end of route&lt;/div&gt;`)[0];
#                 popup_a25ce0207e7a5d663f50dd2cb51426d0.setContent(html_5f7fdf16ba361f795283efeee8a9d756);
#
#
#
#         marker_83f37abd906477716b9294e87282fa45.bindPopup(popup_a25ce0207e7a5d663f50dd2cb51426d0)
#         ;
#
#
#
#
#             marker_83f37abd906477716b9294e87282fa45.bindTooltip(
#                 `&lt;div&gt;
#                      🏭 Warehouse (TER_RUH) (start / end)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_83f37abd906477716b9294e87282fa45.setIcon(icon_7a781bddbd9f25eba95b1525d9aa6c3f);
#
#
#             var marker_6d0e5c8aa49481dbdf9d418c4ce54fe0 = L.marker(
#                 [24.666298, 46.731369],
#                 {
# }
#             ).addTo(map_b882125030953ae462baccc1e900fe2b);
#
#
#             var div_icon_f9765fe6e1345145019b34916ef071b3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;background:red;color:white;\n                             border-radius:50%;width:26px;height:26px;\n                             text-align:center;line-height:26px;\n                             font-weight:bold;font-size:11px;\n                             border:2px solid white;\&quot;\u003e1\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_6d0e5c8aa49481dbdf9d418c4ce54fe0.bindTooltip(
#                 `&lt;div&gt;
#                      [SAL_RUH_001] 1. Al Ghamdi Trading Corner Market [Hibern

# %%
from saudi_multi_salesperson_scheduler_old import MultiSalespersonScheduler, build_route_map_for_salesperson
scheduler = MultiSalespersonScheduler(
    extra_champion_bonus=30,
    solver_time_seconds=60,
)

result = scheduler.create_schedules(
    customer_df      = customer_df,
    rfm_scores_df    = rfm_scores_df,
    salesperson_df   = salesperson_df,
    holiday_df       = holiday_df,
    territory_df     = territory_df,
    config_df        = config_df,
    van_df           = van_df,
    month_start_date = "2026-06-01",
)

# print(result.detailed_schedule.head(20))
# print(result.daily_schedule.head(20))

for sales_id, sp in result.salesperson_results.items():
    print(f"{sales_id} → {len(sp.assigned_customers)} customers, {len(sp.detailed_schedule)} visits")
    
m = build_route_map_for_salesperson(
    daily_schedule    = result.daily_schedule,
    detailed_schedule = result.detailed_schedule,
    sales_id          = "SAL_DMM_001",
    schedule_date     = "2026-06-14",
)
m
# Out:
# Status: OPTIMAL
# Objective value: 64656255.0
# Best bound: 64656255.0
# Status: OPTIMAL
# Objective value: 43551210.0
# Best bound: 43551210.0
# Status: OPTIMAL
# Objective value: 64630255.0
# Best bound: 64630255.0
# Status: OPTIMAL
# Objective value: 48447255.0
# Best bound: 48447255.0
# Status: OPTIMAL
# Objective value: 45370210.0
# Best bound: 45370210.0
# Status: OPTIMAL
# Objective value: 80770315.0
# Best bound: 80770315.0
# Status: OPTIMAL
# Objective value: 80775405.0
# Best bound: 80775405.0
# Status: OPTIMAL
# Objective value: 75808240.0
# Best bound: 75808240.0
# SAL_RUH_001 → 43 customers, 64 visits
# SAL_RUH_002 → 14 customers, 43 visits
# SAL_RUH_003 → 43 customers, 64 visits
# SAL_JED_001 → 20 customers, 48 visits
# SAL_JED_003 → 19 customers, 45 visits
# SAL_DMM_001 → 32 customers, 80 visits
# SAL_DMM_002 → 33 customers, 80 visits
# SAL_DMM_003 → 35 customers, 75 visits
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fb23c86eac564bc972ecae0c0f9b212 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;top:10px;left:60px;z-index:1000;
#                 background:white;padding:8px 12px;border-radius:6px;
#                 border:1px solid #ccc;font-family:sans-serif;&quot;&gt;
#         &lt;b&gt;SAL_DMM_001&lt;/b&gt; — 14 Jun 2026 &amp;nbsp;|&amp;nbsp;
#         5 stops
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fb23c86eac564bc972ecae0c0f9b212&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fb23c86eac564bc972ecae0c0f9b212 = L.map(
#                 &quot;map_7fb23c86eac564bc972ecae0c0f9b212&quot;,
#                 {
#                     center: [26.429597, 50.072714399999995],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ddc29e5e717c6cefaa3abe3ce8ffdb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ddc29e5e717c6cefaa3abe3ce8ffdb2.addTo(map_7fb23c86eac564bc972ecae0c0f9b212);
#
#
#             var marker_c1a0a66017467d92b94b5de9c720670f = L.marker(
#                 [26.397293, 50.045975],
#                 {
# }
#             ).addTo(map_7fb23c86eac564bc972ecae0c0f9b212);
#
#
#             var div_icon_63e1e763cbfc4b1b57bf5509ed022687 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:red;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e1\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_c1a0a66017467d92b94b5de9c720670f.bindTooltip(
#                 `&lt;div&gt;
#                      1. Al Riyadh Corner Market [Champion] Al Badiyah – Cold: False
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_c1a0a66017467d92b94b5de9c720670f.setIcon(div_icon_63e1e763cbfc4b1b57bf5509ed022687);
#
#
#             var marker_79f0afa0dd449c36618ce96e26fa2430 = L.marker(
#                 [26.425781, 50.04286],
#                 {
# }
#             ).addTo(map_7fb23c86eac564bc972ecae0c0f9b212);
#
#
#             var div_icon_9e462b4d71ddc2c8cee88ecc00e6df62 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:blue;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e2\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_79f0afa0dd449c36618ce96e26fa2430.bindTooltip(
#                 `&lt;div&gt;
#                      2. Al Anazi Trading Market [Loyal] Al Nuzha – Cold: False
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_79f0afa0dd449c36618ce96e26fa2430.setIcon(div_icon_9e462b4d71ddc2c8cee88ecc00e6df62);
#
#
#             var marker_92d995b469f436550a9eba845d0405f6 = L.marker(
#                 [26.428519, 50.078974],
#                 {
# }
#             ).addTo(map_7fb23c86eac564bc972ecae0c0f9b212);
#
#
#             var div_icon_20ff096056c75ed08241eae7e8fffad0 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:red;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e3\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_92d995b469f436550a9eba845d0405f6.bindTooltip(
#                 `&lt;div&gt;
#                      3. Al Rajhi Trading Sweets &amp; Bakery [Champion

# %%
m = build_route_map_for_salesperson(
    daily_schedule    = result.daily_schedule,
    detailed_schedule = result.detailed_schedule,
    sales_id          = "SAL_JED_001",
    schedule_date     = "2026-06-30",
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_144de89fba4ea38922a395e43e4a4a56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;top:10px;left:60px;z-index:1000;
#                 background:white;padding:8px 12px;border-radius:6px;
#                 border:1px solid #ccc;font-family:sans-serif;&quot;&gt;
#         &lt;b&gt;SAL_JED_001&lt;/b&gt; — 30 Jun 2026 &amp;nbsp;|&amp;nbsp;
#         3 stops
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_144de89fba4ea38922a395e43e4a4a56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_144de89fba4ea38922a395e43e4a4a56 = L.map(
#                 &quot;map_144de89fba4ea38922a395e43e4a4a56&quot;,
#                 {
#                     center: [21.573802, 39.180867666666664],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42286fc730a124024d1699f667d4cb6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42286fc730a124024d1699f667d4cb6f.addTo(map_144de89fba4ea38922a395e43e4a4a56);
#
#
#             var marker_9bfcc1540106e22c8cf4c1f7f950e1b1 = L.marker(
#                 [21.556895, 39.165497],
#                 {
# }
#             ).addTo(map_144de89fba4ea38922a395e43e4a4a56);
#
#
#             var div_icon_232d772d3652c4a50114819178829558 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:purple;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e1\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_9bfcc1540106e22c8cf4c1f7f950e1b1.bindTooltip(
#                 `&lt;div&gt;
#                      1. Al Shehri Mini Market [Need Attention] Al Rawdah – Cold: False
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_9bfcc1540106e22c8cf4c1f7f950e1b1.setIcon(div_icon_232d772d3652c4a50114819178829558);
#
#
#             var marker_51e6a88029d48906dd749a8038476598 = L.marker(
#                 [21.555739, 39.148456],
#                 {
# }
#             ).addTo(map_144de89fba4ea38922a395e43e4a4a56);
#
#
#             var div_icon_3efd447b96c002ba39a7e9b4e1efce84 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:red;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e2\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_51e6a88029d48906dd749a8038476598.bindTooltip(
#                 `&lt;div&gt;
#                      2. Al Shammari Market [Champion] Al Rawdah – Cold: True
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_51e6a88029d48906dd749a8038476598.setIcon(div_icon_3efd447b96c002ba39a7e9b4e1efce84);
#
#
#             var marker_aa8fd3789f6490af8f13b4b76240f977 = L.marker(
#                 [21.608772, 39.22865],
#                 {
# }
#             ).addTo(map_144de89fba4ea38922a395e43e4a4a56);
#
#
#             var div_icon_6736b5318e6b45f0cd6f4fa67db56707 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:red;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e3\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_aa8fd3789f6490af8f13b4b76240f977.bindTooltip(
#                 `&lt;div&gt;
#                      3. Al Noor Supermarket [Champion] Al Safa – Co

# %%
m = build_route_map_for_salesperson(
    daily_schedule    = result.daily_schedule,
    detailed_schedule = result.detailed_schedule,
    sales_id          = "SAL_RUH_003",
    schedule_date     = "2026-06-09",
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1daec82e544a579ca8f168d2410c10b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-textpath@1.2.3/leaflet.textpath.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position:fixed;top:10px;left:60px;z-index:1000;
#                 background:white;padding:8px 12px;border-radius:6px;
#                 border:1px solid #ccc;font-family:sans-serif;&quot;&gt;
#         &lt;b&gt;SAL_RUH_003&lt;/b&gt; — 09 Jun 2026 &amp;nbsp;|&amp;nbsp;
#         4 stops
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1daec82e544a579ca8f168d2410c10b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1daec82e544a579ca8f168d2410c10b8 = L.map(
#                 &quot;map_1daec82e544a579ca8f168d2410c10b8&quot;,
#                 {
#                     center: [24.7560765, 46.6542165],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_072965cc0510e57bcae12e953de7d765 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_072965cc0510e57bcae12e953de7d765.addTo(map_1daec82e544a579ca8f168d2410c10b8);
#
#
#             var marker_18d8f0d77b60df2b8d327e3426bef07c = L.marker(
#                 [24.706633, 46.70843],
#                 {
# }
#             ).addTo(map_1daec82e544a579ca8f168d2410c10b8);
#
#
#             var div_icon_5b220748d5ae86513e85dc020110dbcf = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:gray;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e1\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_18d8f0d77b60df2b8d327e3426bef07c.bindTooltip(
#                 `&lt;div&gt;
#                      1. Al Malki Trading Cold Store [Hibernating] Al Sulaymaniyah – Cold: True
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_18d8f0d77b60df2b8d327e3426bef07c.setIcon(div_icon_5b220748d5ae86513e85dc020110dbcf);
#
#
#             var marker_e7af4f19bc236d533361e87f6774c23d = L.marker(
#                 [24.718654, 46.701491],
#                 {
# }
#             ).addTo(map_1daec82e544a579ca8f168d2410c10b8);
#
#
#             var div_icon_558a1471d4ecc32f8e1daab7a86ed6e8 = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:purple;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e2\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_e7af4f19bc236d533361e87f6774c23d.bindTooltip(
#                 `&lt;div&gt;
#                      2. Al Qassim Chilled Foods [Need Attention] Al Sulaymaniyah – Cold: True
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_e7af4f19bc236d533361e87f6774c23d.setIcon(div_icon_558a1471d4ecc32f8e1daab7a86ed6e8);
#
#
#             var marker_181fb9c2926832c4191859076e5f3f7c = L.marker(
#                 [24.769194, 46.600485],
#                 {
# }
#             ).addTo(map_1daec82e544a579ca8f168d2410c10b8);
#
#
#             var div_icon_f121aab184f8be32b7785472d803a8cd = L.divIcon({
#   &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;\n                    background:gray;\n                    color:white;\n                    border-radius:50%;\n                    width:26px;\n                    height:26px;\n                    text-align:center;\n                    line-height:26px;\n                    font-weight:bold;\n                    font-size:11px;\n                \&quot;\u003e3\u003c/div\u003e\n                &quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#             marker_181fb9c2926832c4191859076e5f3f7c.bindTooltip(
#                 `&lt;div&gt;
#                      3. Al Waha Fresh Mini Mark

# %%
result
# Out:
# MultiScheduleResult(detailed_schedule=    schedule_date     sales_id territory_id   customer_id  \
# 0      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0001
# 1      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0002
# 2      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0019
# 3      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0080
# 4      2026-06-09  SAL_DMM_001      TER_DMM  CUS_DMM_0098
# ..            ...          ...          ...           ...
# 494    2026-06-29  SAL_RUH_003      TER_RUH  CUS_RUH_0072
# 495    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0002
# 496    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0005
# 497    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0017
# 498    2026-06-30  SAL_RUH_003      TER_RUH  CUS_RUH_0085
#
#                          shop_name         locality    gps_lat    gps_lng  \
# 0     Al Shehri Trading Fresh Meat     Al Mazruiyah  26.456625  50.084601
# 1         Al Safa Catering Kitchen         Al Shati  26.485366  50.117601
# 2    Al Tazaj Hospitality Supplies       Al Badiyah  26.431079  50.059445
# 3         Al Dana Fresh Food Store     Al Mazruiyah  26.436857  50.108580
# 4           Al Rawabi Fresh Baqala         Al Nuzha  26.439413  50.056715
# ..                             ...              ...        ...        ...
# 494              Al Mutairi Baqala        Al Yasmin  24.834435  46.626288
# 495      Al Othman Banquet Kitchen           Hittin  24.780751  46.599296
# 496        Al Manar Fresh Butchery        Al Yasmin  24.829825  46.606460
# 497             Al Rawabi Roastery         Al Malaz  24.671470  46.713252
# 498        Al Anazi Trading Bakery  Al Sulaymaniyah  24.725098  46.723998
#
#             segment lifecycle_state  cold_truck_required  \
# 0             Loyal          Active                 True
# 1          Champion          Active                 True
# 2    Need Attention          Active                 True
# 3          Champion          Active                False
# 4             Loyal          Active                False
# ..              ...             ...                  ...
# 494         At Risk          Active                False
# 495           Loyal          Active                 True
# 496        Champion          Active                 True
# 497        Champion          Active                 True
# 498        Champion          Active                False
#
#      estimated_visit_minutes  estimated_travel_minutes
# 0                         22                        74
# 1                         22                        82
# 2                         22                        69
# 3                         22                        63
# 4                         22                        72
# ..                       ...                       ...
# 494                       22                       130
# 495                       22                       119
# 496                       22                       133
# 497                       22                        56
# 498                       22                        71
#
# [499 rows x 13 columns], daily_schedule=    schedule_date     sales_id territory_id  \
# 0      2026-06-09  SAL_DMM_001      TER_DMM
# 1      2026-06-14  SAL_DMM_001      TER_DMM
# 2      2026-06-15  SAL_DMM_001      TER_DMM
# 3      2026-06-16  SAL_DMM_001      TER_DMM
# 4      2026-06-17  SAL_DMM_001      TER_DMM
# ..            ...          ...          ...
# 121    2026-06-25  SAL_RUH_003      TER_RUH
# 122    2026-06-27  SAL_RUH_003      TER_RUH
# 123    2026-06-28  SAL_RUH_003      TER_RUH
# 124    2026-06-29  SAL_RUH_003      TER_RUH
# 125    2026-06-30  SAL_RUH_003      TER_RUH
#
#                                          customer_list  customer_count  \
# 0    [CUS_DMM_0080, CUS_DMM_0001, CUS_DMM_0098, CUS...               5
# 1    [CUS_DMM_0012, CUS_DMM_0056, CUS_DMM_0067, CUS...               5
# 2    [CUS_DMM_0053, CUS_DMM_0099, CUS_DMM_0009, CUS...               5
# 3    [CUS_DMM_0051, CUS_DMM_0098, CUS_DMM_0001, CUS...               5
# 4    [CUS_DMM_0080, CUS_DMM_0096, CUS_DMM_0066, CUS...               5
# ..                                                 ...             ...
# 121  [CUS_RUH_0011, CUS_RUH_0085, CUS_RUH_0042, CUS...               4
# 122  [CUS_RUH_0066, CUS_RUH_0053, CUS_RUH_0006, CUS...               4
# 123  [CUS_RUH_0034, CUS_RUH_0035, CUS_RUH_0092, CUS...               4
# 124  [CUS_RUH_0020, CUS_RUH_0053, CUS_RUH_0040, CUS...               4
# 125  [CUS_RUH_0017, CUS_RUH_0085, CUS_RUH_0002, CUS...               4
#
#                                            route_order  total_visit_min  \
# 0    [Al Dana Fresh Food Store, Al Shehri Trading F...              110
# 1    [Al Riyadh Corner Market, Al Anazi Trading Mar...              110
# 2    [Al Rashid Trading Baqala, Al Tazaj Al Mazruiy...              110
# 3    [Al Subaie Trading Bakery, Al Rawabi Fresh Baq...              110
# 4    [Al Dana Fresh Food Store, Al Manar Butchery, ...              110
# ..                                                 ...              ...
# 121  [Al Noor Fresh Cafe, Al Anazi Trading Bakery, ...               88
# 122  [Al Khaleej Fresh Cold Store, Al Dana Chilled ...               88
# 123  [Al Jazeera Baqala, Al Malki Trading Catering ...               88
# 124  [Al Madina Chilled Foods, Al Dana Chilled Food...               88
# 125  [Al Rawabi Roastery, Al Anazi Trading Bakery, ...               88
#
#      total_travel_min
# 0                 360
# 1                 334
# 2                 370
# 3                 370
# 4                 370
# ..                ...
# 121               371
# 122               387
# 123               308
# 124               383
# 125               379
#
# [126 rows x 8 columns], salesperson_results={'SAL_RUH_001': SalespersonScheduleResult(sales_id='SAL_RUH_001', territory_id='TER_RUH', detailed_schedule=   schedule_date     sales_id territory_id   customer_id  \
# 0     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0021
# 1     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0056
# 2     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0093
# 3     2026-06-09  SAL_RUH_001      TER_RUH  CUS_RUH_0100
# 4     2026-06-14  SAL_RUH_001      TER_RUH  CUS_RUH_0004
# ..           ...          ...          ...           ...
# 59    2026-06-29  SAL_RUH_001      TER_RUH  CUS_RUH_0099
# 60    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0021
# 61    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0049
# 62    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0067
# 63    2026-06-30  SAL_RUH_001      TER_RUH  CUS_RUH_0093
#
#                        shop_name         locality    gps_lat    gps_lng  \
# 0   Al Subaie Trading Restaurant         Al Malaz  24.662204  46.732799
# 1   Al Rashid Trading Hyper Mini        Al Yasmin  24.831748  46.640400
# 2          Al Jazeera Fresh Cafe           Hittin  24.765842  46.594756
# 3                Al Harbi Market  Al Sulaymaniyah  24.704661  46.721276
# 4             Al Waha Fresh Meat           Hittin  24.769710  46.596453
# ..                           ...              ...        ...        ...
# 59                  Olaya Baqala            Olaya  24.715520  46.666010
# 60  Al Subaie Trading Restaurant         Al Malaz  24.662204  46.732799
# 61     Al Shammari Corner Market            Olaya  24.714427  46.684292
# 62           Al Noor Mini Market  Al Sulaymaniyah  24.701856  46.697032
# 63         Al Jazeera Fresh Cafe           Hittin  24.765842  46.594756
#
#            segment lifecycle_state  cold_truck_required  \
# 0         Champion             New                False
# 1   Need Attention          Active                 True
# 2         Champion          Active                False
# 3      Hibernating         At Risk                 True
# 4         Champion          Active                 True
# ..             ...             ...                  ...
# 59  Need Attention          Active                False
# 60        Champion             New                False
# 61        Champion          Active                False
# 62        Champion          Active                False
# 63        Champion          Active                False
#
#     estimated_visit_minutes  estimated_travel_minutes
# 0                        22                        48
# 1                        22                       126
# 2                        22                       116
# 3                        22                        65
# 4                        22                       117
# ..                      ...                       ...
# 59                       22                        82
# 60                       22                        48
# 61                       22                        77
# 62                       22                        70
# 63                       22                       116
#
# [64 rows x 13 columns], daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_RUH_001      TER_RUH
# 1     2026-06-14  SAL_RUH_001      TER_RUH
# 2     2026-06-15  SAL_RUH_001      TER_RUH
# 3     2026-06-16  SAL_RUH_001      TER_RUH
# 4     2026-06-17  SAL_RUH_001      TER_RUH
# 5     2026-06-18  SAL_RUH_001      TER_RUH
# 6     2026-06-20  SAL_RUH_001      TER_RUH
# 7     2026-06-21  SAL_RUH_001      TER_RUH
# 8     2026-06-22  SAL_RUH_001      TER_RUH
# 9     2026-06-23  SAL_RUH_001      TER_RUH
# 10    2026-06-24  SAL_RUH_001      TER_RUH
# 11    2026-06-25  SAL_RUH_001      TER_RUH
# 12    2026-06-27  SAL_RUH_001      TER_RUH
# 13    2026-06-28  SAL_RUH_001      TER_RUH
# 14    2026-06-29  SAL_RUH_001      TER_RUH
# 15    2026-06-30  SAL_RUH_001      TER_RUH
#
#                                         customer_list  customer_count  \
# 0   [CUS_RUH_0021, CUS_RUH_0100, CUS_RUH_0093, CUS...               4
# 1   [CUS_RUH_0090, CUS_RUH_0029, CUS_RUH_0004, CUS...               4
# 2   [CUS_RUH_0094, CUS_RUH_0007, CUS_RUH_0004, CUS...               4
# 3   [CUS_RUH_0021, CUS_RUH_0049, CUS_RUH_0093, CUS...               4
# 4   [CUS_RUH_0075, CUS_RUH_0067, CUS_RUH_0063, CUS...               4
# 5   [CUS_RUH_0018, CUS_RUH_0087, CUS_RUH_0078, CUS...               4
# 6   [CUS_RUH_0090, CUS_RUH_0054, CUS_RUH_0076, CUS...               4
# 7   [CUS_RUH_0090, CUS_RUH_0037, CUS_RUH_0004, CUS...               4
# 8   [CUS_RUH_0054, CUS_RUH_0049, CUS_RUH_0047, CUS...               4
# 9   [CUS_RUH_0043, CUS_RUH_0021, CUS_RUH_0069, CUS...               4
# 10  [CUS_RUH_0067, CUS_RUH_0049, CUS_RUH_0008, CUS...               4
# 11  [CUS_RUH_0050, CUS_RUH_0022, CUS_RUH_0097, CUS...               4
# 12  [CUS_RUH_0070, CUS_RUH_0054, CUS_RUH_0030, CUS...               4
# 13  [CUS_RUH_0090, CUS_RUH_0067, CUS_RUH_0004, CUS...               4
# 14  [CUS_RUH_0012, CUS_RUH_0054, CUS_RUH_0099, CUS...               4
# 15  [CUS_RUH_0021, CUS_RUH_0067, CUS_RUH_0049, CUS...               4
#
#                                           route_order  total_visit_min  \
# 0   [Al Subaie Trading Restaurant, Al Harbi Market...               88
# 1   [Al Nakheel Grill, Al Tazaj Meat Shop, Al Waha...               88
# 2   [Al Othman Sweets & Bakery, Olaya Grill, Al Wa...               88
# 3   [Al Subaie Trading Restaurant, Al Shammari Cor...               88
# 4   [Al Nada Fresh Chilled Foods, Al Noor Mini Mar...               88
# 5   [Al Rawabi Baqala, Al Nakheel Fresh Hyper Mini...               88
# 6   [Al Nakheel Grill, Al Manar Al Sulaymaniyah Co...               88
# 7   [Al Nakheel Grill, Al Dana Oven, Al Waha Fresh...               88
# 8   [Al Manar Al Sulaymaniyah Cold Store, Al Shamm...               88
# 9   [Al Ghamdi Trading Hospitality Supplies, Al Su...               88
# 10  [Al Noor Mini Market, Al Shammari Corner Marke...               88
# 11  [Al Dana Fresh Coffee House, Al Tazaj Fresh Me...               88
# 12  [Al Khaleej Al Sulaymaniyah Baqala, Al Manar A...               88
# 13  [Al Nakheel Grill, Al Noor Mini Market, Al Wah...               88
# 14  [Al Manar Al Malaz Hotel Kitchen, Al Manar Al ...               88
# 15  [Al Subaie Trading Restaurant, Al Noor Mini Ma...               88
#
#     total_travel_min
# 0                355
# 1                365
# 2                370
# 3                370
# 4                309
# 5                385
# 6                379
# 7                380
# 8                357
# 9                325
# 10               383
# 11               389
# 12               301
# 13               379
# 14               320
# 15               311  , assigned_customers=     customer_id                                shop_name    gps_lat  \
# 0   CUS_RUH_0004                       Al Waha Fresh Meat  24.769710
# 3   CUS_RUH_0021             Al Subaie Trading Restaurant  24.662204
# 6   CUS_RUH_0037                             Al Dana Oven  24.714400
# 9   CUS_RUH_0049                Al Shammari Corner Market  24.714427
# 12  CUS_RUH_0067                      Al Noor Mini Market  24.701856
# 15  CUS_RUH_0090                         Al Nakheel Grill  24.685095
# 18  CUS_RUH_0093                    Al Jazeera Fresh Cafe  24.765842
# 20  CUS_RUH_0012          Al Manar Al Malaz Hotel Kitchen  24.655689
# 22  CUS_RUH_0028    Al Rajhi Trading Hospitality Supplies  24.671622
# 24  CUS_RUH_0043   Al Ghamdi Trading Hospitality Supplies  24.656445
# 26  CUS_RUH_0075              Al Nada Fresh Chilled Foods  24.675328
# 28  CUS_RUH_0029                       Al Tazaj Meat Shop  24.692095
# 30  CUS_RUH_0054      Al Manar Al Sulaymaniyah Cold Store  24.708594
# 32  CUS_RUH_0063               Al Waha Fresh Frozen Foods  24.706529
# 35  CUS_RUH_0100                          Al Harbi Market  24.704661
# 37  CUS_RUH_0023                Al Tazaj Fresh Restaurant  24.826289
# 39  CUS_RUH_0026          Al Madina Fresh Banquet Kitchen  24.836356
# 41  CUS_RUH_0045            Al Dossari Trading Hyper Mini  24.815137
# 43  CUS_RUH_0056             Al Rashid Trading Hyper Mini  24.831748
# 45  CUS_RUH_0078                     Al Qassim Cold Store  24.829538
# 47  CUS_RUH_0084          Al Baraka Fresh Banquet Kitchen  24.831661
# 50  CUS_RUH_0008                              Hittin Cafe  24.761057
# 51  CUS_RUH_0022                      Al Tazaj Fresh Meat  24.750129
# 54  CUS_RUH_0069              Al Riyadh Hittin Hyper Mini  24.748086
# 56  CUS_RUH_0076            Al Harbi Hospitality Supplies  24.775863
# 58  CUS_RUH_0097       Al Safa Fresh Hospitality Supplies  24.766764
# 60  CUS_RUH_0007                              Olaya Grill  24.701275
# 62  CUS_RUH_0030                           Al Tazaj Grill  24.715202
# 65  CUS_RUH_0047  Al Mutairi Trading Hospitality Supplies  24.720661
# 66  CUS_RUH_0065                    Al Dana Hotel Kitchen  24.713911
# 69  CUS_RUH_0087              Al Nakheel Fresh Hyper Mini  24.716498
# 71  CUS_RUH_0009                Al Nada Fresh Mini Market  24.661470
# 74  CUS_RUH_0018                         Al Rawabi Baqala  24.663263
# 76  CUS_RUH_0050               Al Dana Fresh Coffee House  24.652730
# 79  CUS_RUH_0094                Al Othman Sweets & Bakery  24.663261
# 83  CUS_RUH_0070        Al Khaleej Al Sulaymaniyah Baqala  24.706986
# 84  CUS_RUH_0003              Al Qassim Al Yasmin Grocery  24.844884
# 87  CUS_RUH_0044           Al Nada Fresh Catering Kitchen  24.821430
# 90  CUS_RUH_0073                    Al Rawabi Mini Market  24.818397
# 93  CUS_RUH_0089                 Al Nakheel Corner Market  24.824256
# 95  CUS_RUH_0027                 Al Nakheel Fresh Kitchen  24.764633
# 97  CUS_RUH_0083                         Al Baraka Bakery  24.758252
# 99  CUS_RUH_0099                             Olaya Baqala  24.715520
#
#       gps_lng         locality territory_id  customer_rating  review_rating  \
# 0   46.596453           Hittin      TER_RUH                2            3.7
# 3   46.732799         Al Malaz      TER_RUH                2            3.4
# 6   46.673677            Olaya      TER_RUH                4            2.9
# 9   46.684292            Olaya      TER_RUH                3            3.3
# 12  46.697032  Al Sulaymaniyah      TER_RUH                5            4.2
# 15  46.705745  Al Sulaymaniyah      TER_RUH                5            4.1
# 18  46.594756           Hittin      TER_RUH                2            4.0
# 20  46.745293         Al Malaz      TER_RUH                4            3.3
# 22  46.753414         Al Malaz      TER_RUH                1            3.7
# 24  46.728082         Al Malaz      TER_RUH                4            4.1
# 26  46.715115         Al Malaz      TER_RUH                2            3.7
# 28  46.704980  Al Sulaymaniyah      TER_RUH                2            4.5
# 30  46.699118  Al Sulaymaniyah      TER_RUH                1            4.4
# 32  46.710297  Al Sulaymaniyah      TER_RUH                4            3.5
# 35  46.721276  Al Sulaymaniyah      TER_RUH                4            4.3
# 37  46.642652        Al Yasmin      TER_RUH                2            4.2
# 39  46.631280        Al Yasmin      TER_RUH                1            3.8
# 41  46.636076        Al Yasmin      TER_RUH                4            3.5
# 43  46.640400        Al Yasmin      TER_RUH                2            5.0
# 45  46.630765        Al Yasmin      TER_RUH                4            3.6
# 47  46.614555        Al Yasmin      TER_RUH                5            4.5
# 50  46.603037           Hittin      TER_RUH                3            3.2
# 51  46.612277           Hittin      TER_RUH                3            4.7
# 54  46.590569           Hittin      TER_RUH                1            4.3
# 56  46.602997           Hittin      TER_RUH                3            3.4
# 58  46.594477           Hittin      TER_RUH                4            3.9
# 60  46.657092            Olaya      TER_RUH                5            4.8
# 62  46.668033            Olaya      TER_RUH                3            4.3
# 65  46.659342            Olaya      TER_RUH                2            4.1
# 66  46.659157            Olaya      TER_RUH                4            4.1
# 69  46.684203            Olaya      TER_RUH                5            3.5
# 71  46.736475         Al Malaz      TER_RUH                3            3.4
# 74  46.726712         Al Malaz      TER_RUH                5            4.3
# 76  46.741568         Al Malaz      TER_RUH                5            4.2
# 79  46.736507         Al Malaz      TER_RUH                4            4.4
# 83  46.717584  Al Sulaymaniyah      TER_RUH                3            5.0
# 84  46.639722        Al Yasmin      TER_RUH                5            3.7
# 87  46.610959        Al Yasmin      TER_RUH                5            4.0
# 90  46.627262        Al Yasmin      TER_RUH                2            3.7
# 93  46.614717        Al Yasmin      TER_RUH                3            4.9
# 95  46.577551           Hittin      TER_RUH                3            3.9
# 97  46.594098           Hittin      TER_RUH                3            5.0
# 99  46.666010            Olaya      TER_RUH                4            4.5
#
#        shop_category  cold_truck_required  ... preferred_order_window recency  \
# 0           Butchery                 True  ...                 Midday      13
# 3         Restaurant                False  ...              Afternoon       8
# 6             Bakery                False  ...                 Midday       8
# 9        Mini Market                False  ...              Afternoon      11
# 12       Mini Market                False  ...                Morning       5
# 15        Restaurant                False  ...              Afternoon       3
# 18              Cafe                False  ...                Morning      17
# 20     Hotel Kitchen                 True  ...              Afternoon      11
# 22     Hotel Kitchen                 True  ...                 Midday     224
# 24     Hotel Kitchen                 True  ...              Afternoon      41
# 26        Cold Store                 True  ...              Afternoon      90
# 28          Butchery                 True  ...                Morning      29
# 30        Cold Store                 True  ...                 Midday      22
# 32        Cold Store                 True  ...              Afternoon      51
# 35       Supermarket                 True  ...                Morning      84
# 37        Restaurant                 True  ...              Afternoon      52
# 39  Catering Kitchen                 True  ...              Afternoon     100
# 41       Supermarket                 True  ...                Morning     147
# 43       Supermarket                 True  ...                 Midday      32
# 45        Cold Store                 True  ...              Afternoon      13
# 47  Catering Kitchen                 True  ...                 Midday       4
# 50              Cafe                 True  ...                 Midday      13
# 51          Butchery                 True  ...              Afternoon      22
# 54       Supermarket                 True  ...                 Midday      64
# 56     Hotel Kitchen                 True  ...                Morning       5
# 58     Hotel Kitchen                 True  ...                Morning      33
# 60        Restaurant                 True  ...              Afternoon       9
# 62        Restaurant                 True  ...              Afternoon      79
# 65     Hotel Kitchen                 True  ...              Afternoon       2
# 66     Hotel Kitchen                 True  ...              Afternoon      40
# 69       Supermarket                 True  ...                 Midday      66
# 71       Mini Market                False  ...              Afternoon     102
# 74       Mini Market                False  ...                 Midday      60
# 76              Cafe                False  ...              Afternoon      95
# 79            Bakery                False  ...                Morning      78
# 83       Mini Market                False  ...                 Midday      22
# 84           Grocery                False  ...                Morning      96
# 87  Catering Kitchen                False  ...              Afternoon      28
# 90       Mini Market                False  ...                Morning      25
# 93       Mini Market                False  ...                 Midday      46
# 95        Restaurant                False  ...                 Midday      60
# 97            Bakery                False  ...              Afternoon      11
# 99       Mini Market                False  ...              Afternoon      41
#
#     frequency   monetary r_score f_score m_score rfm_score  \
# 0          26   47605.78       4       5       5       455
# 3          16   36457.16       5       4       4       544
# 6          10   54875.52       5       3       5       535
# 9          33   73294.39       5       5       5       555
# 12         42  108134.77       5       5       5       555
# 15         34  149158.09       5       5       5       555
# 18         21  138816.55       4       4       5       445
# 20          4    4222.25       5       2       2       522
# 22          0      23.05       1       1       1       111
# 24         16   26819.39       3       4       4       344
# 26          3    1292.08       1       1       1       111
# 28         18   48483.57       3       4       5       345
# 30         20   44018.82       4       4       4       444
# 32          1   11641.60       3       1       3       313
# 35          5    6265.53       1       2       2       122
# 37         12    8558.01       2       4       3       243
# 39          3   11127.81       1       1       3       113
# 41          1    1466.74       1       1       1       111
# 43          9    8159.09       3       3       3       333
# 45          4    3750.50       4       2       1       421
# 47          3   15513.29       5       1       3       513
# 50         13    9881.75       4       4       3       443
# 51          3    8869.38       4       1       3       413
# 54          8    8931.67       2       3       3       233
# 56          3    1594.91       5       1       1       511
# 58         11   43781.60       3       4       4       344
# 60          4    1053.56       5       2       1       521
# 62          9   11250.86       2       3       3       233
# 65          3     221.65       5       1       1       511
# 66          8    1551.12       3       3       1       331
# 69          4    7468.47       2       2       2       222
# 71          1    1863.86       1       1       1       111
# 74          6    8009.65       2       3       3       233
# 76          2    3686.58       1       1       1       111
# 79          1   10113.80       2       1       3       213
# 83         12    4844.34       4       4       2       442
# 84          5   32151.46       1       2       4       124
# 87          3    2071.18       3       1       1       311
# 90         25   40457.81       4       5       4       454
# 93         11    6151.16       3       4       2       342
# 95         14   16983.06       2       4       4       244
# 97          9   47089.28       5       3       5       535
# 99          3    6824.60       3       1       2       312
#
#                segment  assigned_sales_id
# 0             Champion        SAL_RUH_001
# 3             Champion        SAL_RUH_001
# 6   Potential Loyalist        SAL_RUH_001
# 9             Champion        SAL_RUH_001
# 12            Champion        SAL_RUH_001
# 15            Champion        SAL_RUH_001
# 18            Champion        SAL_RUH_001
# 20  Potential Loyalist        SAL_RUH_001
# 22         Hibernating        SAL_RUH_001
# 24               Loyal        SAL_RUH_001
# 26         Hibernating        SAL_RUH_001
# 28               Loyal        SAL_RUH_001
# 30            Champion        SAL_RUH_001
# 32      Need Attention        SAL_RUH_001
# 35         Hibernating        SAL_RUH_001
# 37               Loyal        SAL_RUH_001
# 39      Need Attention        SAL_RUH_001
# 41         Hibernating        SAL_RUH_001
# 43      Need Attention        SAL_RUH_001
# 45  Potential Loyalist        SAL_RUH_001
# 47      Need Attention        SAL_RUH_001
# 50               Loyal        SAL_RUH_001
# 51      Need Attention        SAL_RUH_001
# 54             At Risk        SAL_RUH_001
# 56      Need Attention        SAL_RUH_001
# 58               Loyal        SAL_RUH_001
# 60  Potential Loyalist        SAL_RUH_001
# 62             At Risk        SAL_RUH_001
# 65      Need Attention        SAL_RUH_001
# 66      Need Attention        SAL_RUH_001
# 69         Hibernating        SAL_RUH_001
# 71         Hibernating        SAL_RUH_001
# 74             At Risk        SAL_RUH_001
# 76         Hibernating        SAL_RUH_001
# 79      Need Attention        SAL_RUH_001
# 83      Need Attention        SAL_RUH_001
# 84      Need Attention        SAL_RUH_001
# 87      Need Attention        SAL_RUH_001
# 90            Champion        SAL_RUH_001
# 93      Need Attention        SAL_RUH_001
# 95               Loyal        SAL_RUH_001
# 97  Potential Loyalist        SAL_RUH_001
# 99      Need Attention        SAL_RUH_001
#
# [43 rows x 27 columns]), 'SAL_RUH_002': SalespersonScheduleResult(sales_id='SAL_RUH_002', territory_id='TER_RUH', detailed_schedule=   schedule_date     sales_id territory_id   customer_id  \
# 0     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0060
# 1     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 2     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 3     2026-06-09  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 4     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0014
# 5     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 6     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 7     2026-06-14  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 8     2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0010
# 9     2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0032
# 10    2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 11    2026-06-15  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 12    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 13    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0060
# 14    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0064
# 15    2026-06-16  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 16    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 17    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 18    2026-06-17  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 19    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 20    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 21    2026-06-18  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 22    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 23    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 24    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 25    2026-06-20  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 26    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 27    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 28    2026-06-21  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 29    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 30    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0032
# 31    2026-06-22  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 32    2026-06-23  SAL_RUH_002      TER_RUH  CUS_RUH_0091
# 33    2026-06-24  SAL_RUH_002      TER_RUH  CUS_RUH_0071
# 34    2026-06-25  SAL_RUH_002      TER_RUH  CUS_RUH_0013
# 35    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0052
# 36    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0077
# 37    2026-06-27  SAL_RUH_002      TER_RUH  CUS_RUH_0096
# 38    2026-06-28  SAL_RUH_002      TER_RUH  CUS_RUH_0025
# 39    2026-06-28  SAL_RUH_002      TER_RUH  CUS_RUH_0079
# 40    2026-06-29  SAL_RUH_002      TER_RUH  CUS_RUH_0032
# 41    2026-06-29  SAL_RUH_002      TER_RUH  CUS_RUH_0038
# 42    2026-06-30  SAL_RUH_002      TER_RUH  CUS_RUH_0091
#
#                               shop_name         locality    gps_lat  \
# 0                  Al Shehri Food Store         Al Malaz  24.683969
# 1                Al Malki Hotel Kitchen            Olaya  24.703445
# 2                 Al Riyadh Supermarket        Al Yasmin  24.843331
# 3          Al Malki Trading Mini Market           Hittin  24.741617
# 4              Al Rashid Trading Market         Al Malaz  24.669817
# 5              Al Shammari Trading Cafe        Al Yasmin  24.826697
# 6                Al Malki Hotel Kitchen            Olaya  24.703445
# 7                  Al Noor Coffee House        Al Yasmin  24.851244
# 8                 Al Ghamdi Mini Market  Al Sulaymaniyah  24.705431
# 9   Al Zahrani Trading Catering Kitchen  Al Sulaymaniyah  24.697510
# 10       Al Mutairi Trading Supermarket            Olaya  24.711201
# 11          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 12                   Al Baraka Butchery           Hittin  24.766215
# 13                 Al Shehri Food Store         Al Malaz  24.683969
# 14                    Al Baraka Kitchen  Al Sulaymaniyah  24.684141
# 15                Al Riyadh Supermarket        Al Yasmin  24.843331
# 16                        Hittin Market           Hittin  24.765952
# 17          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 18         Al Malki Trading Mini Market           Hittin  24.741617
# 19                        Hittin Market           Hittin  24.765952
# 20          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 21                 Al Noor Coffee House        Al Yasmin  24.851244
# 22       Al Mutairi Trading Supermarket            Olaya  24.711201
# 23                   Al Baraka Butchery           Hittin  24.766215
# 24               Al Malki Hotel Kitchen            Olaya  24.703445
# 25         Al Malki Trading Mini Market           Hittin  24.741617
# 26             Al Shammari Trading Cafe        Al Yasmin  24.826697
# 27                   Al Baraka Butchery           Hittin  24.766215
# 28                 Al Noor Coffee House        Al Yasmin  24.851244
# 29                        Hittin Market           Hittin  24.765952
# 30  Al Zahrani Trading Catering Kitchen  Al Sulaymaniyah  24.697510
# 31       Al Mutairi Trading Supermarket            Olaya  24.711201
# 32                Al Riyadh Supermarket        Al Yasmin  24.843331
# 33          Al Riyadh Fresh Mini Market        Al Yasmin  24.833529
# 34                        Hittin Market           Hittin  24.765952
# 35                   Al Baraka Butchery           Hittin  24.766215
# 36               Al Malki Hotel Kitchen            Olaya  24.703445
# 37         Al Malki Trading Mini Market           Hittin  24.741617
# 38             Al Shammari Trading Cafe        Al Yasmin  24.826697
# 39                 Al Noor Coffee House        Al Yasmin  24.851244
# 40  Al Zahrani Trading Catering Kitchen  Al Sulaymaniyah  24.697510
# 41       Al Mutairi Trading Supermarket            Olaya  24.711201
# 42                Al Riyadh Supermarket        Al Yasmin  24.843331
#
#       gps_lng         segment lifecycle_state  cold_truck_required  \
# 0   46.731820  Need Attention          Active                False
# 1   46.683025        Champion          Active                 True
# 2   46.612384        Champion          Active                False
# 3   46.600318        Champion          Active                False
# 4   46.744251     Hibernating         At Risk                False
# 5   46.649614           Loyal          Active                False
# 6   46.683025        Champion          Active                 True
# 7   46.638066        Champion          Active                False
# 8   46.703755     Hibernating         Dormant                False
# 9   46.706340           Loyal         At Risk                 True
# 10  46.675347        Champion             New                 True
# 11  46.644290        Champion          Active                False
# 12  46.605835        Champion          Active                 True
# 13  46.731820  Need Attention          Active                False
# 14  46.705665     Hibernating         Dormant                False
# 15  46.612384        Champion          Active                False
# 16  46.577897        Champion          Active                 True
# 17  46.644290        Champion          Active                False
# 18  46.600318        Champion          Active                False
# 19  46.577897        Champion          Active                 True
# 20  46.644290        Champion          Active                False
# 21  46.638066        Champion          Active                False
# 22  46.675347        Champion             New                 True
# 23  46.605835        Champion          Active                 True
# 24  46.683025        Champion          Active                 True
# 25  46.600318        Champion          Active                False
# 26  46.649614           Loyal          Active                False
# 27  46.605835        Champion          Active                 True
# 28  46.638066        Champion          Active                False
# 29  46.577897        Champion          Active                 True
# 30  46.706340           Loyal         At Risk                 True
# 31  46.675347        Champion             New                 True
# 32  46.612384        Champion          Active                False
# 33  46.644290        Champion          Active                False
# 34  46.577897        Champion          Active                 True
# 35  46.605835        Champion          Active                 True
# 36  46.683025        Champion          Active                 True
# 37  46.600318        Champion          Active                False
# 38  46.649614           Loyal          Active                False
# 39  46.638066        Champion          Active                False
# 40  46.706340           Loyal         At Risk                 True
# 41  46.675347        Champion             New                 True
# 42  46.612384        Champion          Active                False
#
#     estimated_visit_minutes  estimated_travel_minutes
# 0                        22                        55
# 1                        22                        74
# 2                        22                       136
# 3                        22                       108
# 4                        22                        48
# 5                        22                       122
# 6                        22                        74
# 7                        22                       133
# 8                        22                        69
# 9                        22                        66
# 10                       22                        78
# 11                       22                       126
# 12                       22                       113
# 13                       22                        55
# 14                       22                        62
# 15                       22                       136
# 16                       22                       121
# 17                       22                       126
# 18                       22                       108
# 19                       22                       121
# 20                       22                       126
# 21                       22                       133
# 22                       22                        78
# 23                       22                       113
# 24                       22                        74
# 25                       22                       108
# 26                       22                       122
# 27                       22                       113
# 28                       22                       133
# 29                       22                       121
# 30                       22                        66
# 31                       22                        78
# 32                       22                       136
# 33                       22                       126
# 34                       22                       121
# 35                       22                       113
# 36                       22                        74
# 37                       22                       108
# 38                       22                       122
# 39                       22                       133
# 40                       22                        66
# 41                       22                        78
# 42                       22                       136  , daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_RUH_002      TER_RUH
# 1     2026-06-14  SAL_RUH_002      TER_RUH
# 2     2026-06-15  SAL_RUH_002      TER_RUH
# 3     2026-06-16  SAL_RUH_002      TER_RUH
# 4     2026-06-17  SAL_RUH_002      TER_RUH
# 5     2026-06-18  SAL_RUH_002      TER_RUH
# 6     2026-06-20  SAL_RUH_002      TER_RUH
# 7     2026-06-21  SAL_RUH_002      TER_RUH
# 8     2026-06-22  SAL_RUH_002      TER_RUH
# 9     2026-06-23  SAL_RUH_002      TER_RUH
# 10    2026-06-24  SAL_RUH_002      TER_RUH
# 11    2026-06-25  SAL_RUH_002      TER_RUH
# 12    2026-06-27  SAL_RUH_002      TER_RUH
# 13    2026-06-28  SAL_RUH_002      TER_RUH
# 14    2026-06-29  SAL_RUH_002      TER_RUH
# 15    2026-06-30  SAL_RUH_002      TER_RUH
#
#                                         customer_list  customer_count  \
# 0   [CUS_RUH_0060, CUS_RUH_0077, CUS_RUH_0096, CUS...               4
# 1   [CUS_RUH_0014, CUS_RUH_0077, CUS_RUH_0025, CUS...               4
# 2   [CUS_RUH_0032, CUS_RUH_0010, CUS_RUH_0038, CUS...               4
# 3   [CUS_RUH_0060, CUS_RUH_0064, CUS_RUH_0052, CUS...               4
# 4          [CUS_RUH_0096, CUS_RUH_0013, CUS_RUH_0071]               3
# 5          [CUS_RUH_0013, CUS_RUH_0071, CUS_RUH_0079]               3
# 6   [CUS_RUH_0077, CUS_RUH_0038, CUS_RUH_0096, CUS...               4
# 7          [CUS_RUH_0052, CUS_RUH_0025, CUS_RUH_0079]               3
# 8          [CUS_RUH_0032, CUS_RUH_0038, CUS_RUH_0013]               3
# 9                                      [CUS_RUH_0091]               1
# 10                                     [CUS_RUH_0071]               1
# 11                                     [CUS_RUH_0013]               1
# 12         [CUS_RUH_0077, CUS_RUH_0096, CUS_RUH_0052]               3
# 13                       [CUS_RUH_0025, CUS_RUH_0079]               2
# 14                       [CUS_RUH_0032, CUS_RUH_0038]               2
# 15                                     [CUS_RUH_0091]               1
#
#                                           route_order  total_visit_min  \
# 0   [Al Shehri Food Store, Al Malki Hotel Kitchen,...               88
# 1   [Al Rashid Trading Market, Al Malki Hotel Kitc...               88
# 2   [Al Zahrani Trading Catering Kitchen, Al Ghamd...               88
# 3   [Al Shehri Food Store, Al Baraka Kitchen, Al B...               88
# 4   [Al Malki Trading Mini Market, Hittin Market, ...               66
# 5   [Hittin Market, Al Riyadh Fresh Mini Market, A...               66
# 6   [Al Malki Hotel Kitchen, Al Mutairi Trading Su...               88
# 7   [Al Baraka Butchery, Al Shammari Trading Cafe,...               66
# 8   [Al Zahrani Trading Catering Kitchen, Al Mutai...               66
# 9                             [Al Riyadh Supermarket]               22
# 10                      [Al Riyadh Fresh Mini Market]               22
# 11                                    [Hittin Market]               22
# 12  [Al Malki Hotel Kitchen, Al Malki Trading Mini...               66
# 13   [Al Shammari Trading Cafe, Al Noor Coffee House]               44
# 14  [Al Zahrani Trading Catering Kitchen, Al Mutai...               44
# 15                            [Al Riyadh Supermarket]               22
#
#     total_travel_min
# 0                373
# 1                377
# 2                339
# 3                366
# 4                355
# 5                380
# 6                373
# 7                368
# 8                265
# 9                136
# 10               126
# 11               121
# 12               295
# 13               255
# 14               144
# 15               136  , assigned_customers=     customer_id                            shop_name    gps_lat    gps_lng  \
# 1   CUS_RUH_0013                        Hittin Market  24.765952  46.577897
# 4   CUS_RUH_0032  Al Zahrani Trading Catering Kitchen  24.697510  46.706340
# 7   CUS_RUH_0038       Al Mutairi Trading Supermarket  24.711201  46.675347
# 10  CUS_RUH_0052                   Al Baraka Butchery  24.766215  46.605835
# 13  CUS_RUH_0077               Al Malki Hotel Kitchen  24.703445  46.683025
# 16  CUS_RUH_0091                Al Riyadh Supermarket  24.843331  46.612384
# 19  CUS_RUH_0096         Al Malki Trading Mini Market  24.741617  46.600318
# 72  CUS_RUH_0014             Al Rashid Trading Market  24.669817  46.744251
# 77  CUS_RUH_0060                 Al Shehri Food Store  24.683969  46.731820
# 80  CUS_RUH_0010                Al Ghamdi Mini Market  24.705431  46.703755
# 82  CUS_RUH_0064                    Al Baraka Kitchen  24.684141  46.705665
# 85  CUS_RUH_0025             Al Shammari Trading Cafe  24.826697  46.649614
# 88  CUS_RUH_0071          Al Riyadh Fresh Mini Market  24.833529  46.644290
# 91  CUS_RUH_0079                 Al Noor Coffee House  24.851244  46.638066
#
#            locality territory_id  customer_rating  review_rating  \
# 1            Hittin      TER_RUH                4            3.3
# 4   Al Sulaymaniyah      TER_RUH                5            3.2
# 7             Olaya      TER_RUH                4            5.0
# 10           Hittin      TER_RUH                5            3.6
# 13            Olaya      TER_RUH                4            3.6
# 16        Al Yasmin      TER_RUH                5            4.6
# 19           Hittin      TER_RUH                3            4.3
# 72         Al Malaz      TER_RUH                1            4.1
# 77         Al Malaz      TER_RUH                4            5.0
# 80  Al Sulaymaniyah      TER_RUH                2            3.8
# 82  Al Sulaymaniyah      TER_RUH                4            4.5
# 85        Al Yasmin      TER_RUH                3            2.6
# 88        Al Yasmin      TER_RUH                5            4.5
# 91        Al Yasmin      TER_RUH                2            2.9
#
#        shop_category  cold_truck_required  ... preferred_order_window recency  \
# 1        Supermarket                 True  ...                Morning      10
# 4   Catering Kitchen                 True  ...                Morning      81
# 7        Supermarket                 True  ...                 Midday       5
# 10          Butchery                 True  ...                 Midday       7
# 13     Hotel Kitchen                 True  ...                 Midday      17
# 16       Supermarket                False  ...              Afternoon       2
# 19       Mini Market                False  ...                 Midday       6
# 72       Supermarket                False  ...                 Midday      85
# 77           Grocery                False  ...                Morning      66
# 80       Mini Market                False  ...                Morning     122
# 82        Restaurant                False  ...                Morning     109
# 85              Cafe                False  ...                 Midday      37
# 88       Mini Market                False  ...              Afternoon      15
# 91              Cafe                False  ...                 Midday      11
#
#     frequency   monetary r_score f_score m_score rfm_score         segment  \
# 1          31   75388.99       5       5       5       555        Champion
# 4          24  120753.54       1       5       5       155           Loyal
# 7          18   48506.49       5       4       5       545        Champion
# 10         48  155438.59       5       5       5       555        Champion
# 13         32  138716.95       4       5       5       455        Champion
# 16         31  111493.08       5       5       5       555        Champion
# 19         37  141125.13       5       5       5       555        Champion
# 72          6    7080.02       1       2       2       122     Hibernating
# 77          1   10432.06       2       1       3       213  Need Attention
# 80          3    6879.02       1       1       2       112     Hibernating
# 82          4    4900.12       1       2       2       122     Hibernating
# 85         25    9583.62       3       5       3       353           Loyal
# 88         16   50135.83       4       4       5       445        Champion
# 91         25   46314.39       5       5       5       555        Champion
#
#     assigned_sales_id
# 1         SAL_RUH_002
# 4         SAL_RUH_002
# 7         SAL_RUH_002
# 10        SAL_RUH_002
# 13        SAL_RUH_002
# 16        SAL_RUH_002
# 19        SAL_RUH_002
# 72        SAL_RUH_002
# 77        SAL_RUH_002
# 80        SAL_RUH_002
# 82        SAL_RUH_002
# 85        SAL_RUH_002
# 88        SAL_RUH_002
# 91        SAL_RUH_002
#
# [14 rows x 27 columns]), 'SAL_RUH_003': SalespersonScheduleResult(sales_id='SAL_RUH_003', territory_id='TER_RUH', detailed_schedule=   schedule_date     sales_id territory_id   customer_id  \
# 0     2026-06-09  SAL_RUH_003      TER_RUH  CUS_RUH_0001
# 1     2026-06-09  SAL_RUH_003      TER_RUH  CUS_RUH_0005
# ...
# 2                        22                        69
# 3                        22                        74
# 4                        22                        65
# ..                      ...                       ...
# 70                       22                        64
# 71                       22                        71
# 72                       22                        74
# 73                       22                        72
# 74                       22                        73
#
# [75 rows x 13 columns], daily_schedule=   schedule_date     sales_id territory_id  \
# 0     2026-06-09  SAL_DMM_003      TER_DMM
# 1     2026-06-14  SAL_DMM_003      TER_DMM
# 2     2026-06-15  SAL_DMM_003      TER_DMM
# 3     2026-06-16  SAL_DMM_003      TER_DMM
# 4     2026-06-17  SAL_DMM_003      TER_DMM
# 5     2026-06-18  SAL_DMM_003      TER_DMM
# 6     2026-06-21  SAL_DMM_003      TER_DMM
# 7     2026-06-22  SAL_DMM_003      TER_DMM
# 8     2026-06-23  SAL_DMM_003      TER_DMM
# 9     2026-06-24  SAL_DMM_003      TER_DMM
# 10    2026-06-25  SAL_DMM_003      TER_DMM
# 11    2026-06-27  SAL_DMM_003      TER_DMM
# 12    2026-06-28  SAL_DMM_003      TER_DMM
# 13    2026-06-29  SAL_DMM_003      TER_DMM
# 14    2026-06-30  SAL_DMM_003      TER_DMM
#
#                                         customer_list  customer_count  \
# 0   [CUS_DMM_0025, CUS_DMM_0055, CUS_DMM_0062, CUS...               5
# 1   [CUS_DMM_0091, CUS_DMM_0052, CUS_DMM_0065, CUS...               5
# 2   [CUS_DMM_0029, CUS_DMM_0077, CUS_DMM_0040, CUS...               5
# 3   [CUS_DMM_0088, CUS_DMM_0058, CUS_DMM_0025, CUS...               5
# 4   [CUS_DMM_0088, CUS_DMM_0058, CUS_DMM_0010, CUS...               5
# 5   [CUS_DMM_0088, CUS_DMM_0021, CUS_DMM_0091, CUS...               5
# 6   [CUS_DMM_0017, CUS_DMM_0093, CUS_DMM_0040, CUS...               5
# 7   [CUS_DMM_0081, CUS_DMM_0010, CUS_DMM_0049, CUS...               5
# 8   [CUS_DMM_0058, CUS_DMM_0052, CUS_DMM_0090, CUS...               5
# 9   [CUS_DMM_0058, CUS_DMM_0072, CUS_DMM_0006, CUS...               5
# 10  [CUS_DMM_0091, CUS_DMM_0030, CUS_DMM_0061, CUS...               5
# 11  [CUS_DMM_0010, CUS_DMM_0093, CUS_DMM_0013, CUS...               5
# 12  [CUS_DMM_0010, CUS_DMM_0093, CUS_DMM_0048, CUS...               5
# 13  [CUS_DMM_0081, CUS_DMM_0052, CUS_DMM_0049, CUS...               5
# 14  [CUS_DMM_0025, CUS_DMM_0090, CUS_DMM_0062, CUS...               5
#
#                                           route_order  total_visit_min  \
# 0   [Al Rawabi Fresh Kitchen, Al Dana Al Badiyah B...              110
# 1   [Al Nada Fresh Hospitality Supplies, Al Manar ...              110
# 2   [Al Othman Trading Butchery, Al Khaleej Fresh ...              110
# 3   [Al Malki Trading Sweets & Bakery, Al Rashid H...              110
# 4   [Al Malki Trading Sweets & Bakery, Al Rashid H...              110
# 5   [Al Malki Trading Sweets & Bakery, Al Dossari ...              110
# 6   [Al Malki Fresh Meat, Al Othman Trading Baqala...              110
# 7   [Al Qahtani Trading Bakery, Al Malki Trading C...              110
# 8   [Al Rashid Hospitality Supplies, Al Manar Fres...              110
# 9   [Al Rashid Hospitality Supplies, Al Safa Fresh...              110
# 10  [Al Nada Fresh Hospitality Supplies, Al Dana F...              110
# 11  [Al Malki Trading Chilled Foods, Al Othman Tra...              110
# 12  [Al Malki Trading Chilled Foods, Al Othman Tra...              110
# 13  [Al Qahtani Trading Bakery, Al Manar Fresh Col...              110
# 14  [Al Rawabi Fresh Kitchen, Al Zahrani Trading B...              110
#
#     total_travel_min
# 0                338
# 1                327
# 2                344
# 3                316
# 4                294
# 5                302
# 6                342
# 7                334
# 8                333
# 9                339
# 10               342
# 11               346
# 12               324
# 13               341
# 14               354  , assigned_customers=     customer_id                           shop_name    gps_lat    gps_lng  \
# 2   CUS_DMM_0010      Al Malki Trading Chilled Foods  26.400683  50.059401
# 5   CUS_DMM_0040                Al Saleh Supermarket  26.449793  50.091627
# 8   CUS_DMM_0052           Al Manar Fresh Cold Store  26.413965  50.046764
# 11  CUS_DMM_0058      Al Rashid Hospitality Supplies  26.395766  50.066651
# 14  CUS_DMM_0077        Al Khaleej Fresh Mini Market  26.443368  50.092656
# 17  CUS_DMM_0093            Al Othman Trading Baqala  26.422371  50.081414
# 21  CUS_DMM_0017                 Al Malki Fresh Meat  26.399499  50.067453
# 25  CUS_DMM_0055  Al Dana Al Badiyah Banquet Kitchen  26.430930  50.057492
# 28  CUS_DMM_0091  Al Nada Fresh Hospitality Supplies  26.400107  50.048663
# 31  CUS_DMM_0025             Al Rawabi Fresh Kitchen  26.424341  50.073929
# 34  CUS_DMM_0065              Al Zahrani Supermarket  26.431258  50.062544
# 36  CUS_DMM_0094                 Al Tazaj Fresh Meat  26.441583  50.110377
# 39  CUS_DMM_0029          Al Othman Trading Butchery  26.434337  50.105168
# 42  CUS_DMM_0037                 Al Malki Hyper Mini  26.424655  50.117537
# 44  CUS_DMM_0048                Al Madina Hyper Mini  26.433690  50.088341
# 46  CUS_DMM_0004                 Al Malki Cold Store  26.450547  50.051529
# 49  CUS_DMM_0061              Al Manar Chilled Foods  26.435701  50.026507
# 53  CUS_DMM_0043                  Al Dana Fresh Meat  26.470308  50.116773
# 56  CUS_DMM_0085              Al Rashid Frozen Foods  26.462922  50.127358
# 59  CUS_DMM_0021  Al Dossari Trading Banquet Kitchen  26.395640  50.051825
# 62  CUS_DMM_0033                      Al Othman Oven  26.405773  50.042970
# 64  CUS_DMM_0081           Al Qahtani Trading Bakery  26.401543  50.067184
# 66  CUS_DMM_0088    Al Malki Trading Sweets & Bakery  26.385031  50.078156
# 70  CUS_DMM_0006              Al Baraka Fresh Market  26.449555  50.097576
# 73  CUS_DMM_0013                      Al Noor Baqala  26.457370  50.097122
# 75  CUS_DMM_0046       Al Subaie Trading Mini Market  26.453422  50.099420
# 79  CUS_DMM_0097              Al Madina Coffee House  26.454752  50.110145
# 81  CUS_DMM_0030          Al Dana Fresh Coffee House  26.429479  50.052241
# 84  CUS_DMM_0049                   Al Riyadh Kitchen  26.439529  50.034173
# 85  CUS_DMM_0062               Al Saleh Coffee House  26.440576  50.050340
# 88  CUS_DMM_0072         Al Safa Fresh Hotel Kitchen  26.435913  50.056277
# 91  CUS_DMM_0090           Al Zahrani Trading Baqala  26.437466  50.051582
# 94  CUS_DMM_0018                     Al Shati Baqala  26.482787  50.109017
# 96  CUS_DMM_0042                  Al Jazeera Grocery  26.478470  50.114549
# 99  CUS_DMM_0087                 Al Waha Supermarket  26.463881  50.120362
#
#          locality territory_id  customer_rating  review_rating  \
# 2      Al Badiyah      TER_DMM                4            4.6
# 5    Al Mazruiyah      TER_DMM                4            4.0
# 8      Al Badiyah      TER_DMM                4            5.0
# 11     Al Badiyah      TER_DMM                3            4.5
# 14   Al Mazruiyah      TER_DMM                5            3.3
# 17  Al Faisaliyah      TER_DMM                5            4.0
# 21     Al Badiyah      TER_DMM                4            5.0
# 25     Al Badiyah      TER_DMM                3            4.6
# 28     Al Badiyah      TER_DMM                3            3.2
# 31  Al Faisaliyah      TER_DMM                3            3.2
# 34  Al Faisaliyah      TER_DMM                4            3.4
# 36  Al Faisaliyah      TER_DMM                4            3.7
# 39   Al Mazruiyah      TER_DMM                4            3.9
# 42   Al Mazruiyah      TER_DMM                2            4.1
# 44   Al Mazruiyah      TER_DMM                4            4.0
# 46       Al Nuzha      TER_DMM                4            4.0
# 49       Al Nuzha      TER_DMM                3            4.2
# 53       Al Shati      TER_DMM                1            3.7
# 56       Al Shati      TER_DMM                3            4.8
# 59     Al Badiyah      TER_DMM                1            4.0
# 62     Al Badiyah      TER_DMM                5            4.5
# 64     Al Badiyah      TER_DMM                5            3.4
# 66     Al Badiyah      TER_DMM                4            5.0
# 70   Al Mazruiyah      TER_DMM                4            4.4
# 73   Al Mazruiyah      TER_DMM                4            3.3
# 75   Al Mazruiyah      TER_DMM                3            4.5
# 79   Al Mazruiyah      TER_DMM                5            4.5
# 81       Al Nuzha      TER_DMM                4            4.2
# 84       Al Nuzha      TER_DMM                4            4.1
# 85       Al Nuzha      TER_DMM                4            4.6
# 88       Al Nuzha      TER_DMM                2            3.2
# 91       Al Nuzha      TER_DMM                4            5.0
# 94       Al Shati      TER_DMM                4            3.4
# 96       Al Shati      TER_DMM                5            3.9
# 99       Al Shati      TER_DMM                4            4.1
#
#        shop_category  cold_truck_required  ... preferred_order_window recency  \
# 2         Cold Store                 True  ...                 Midday      16
# 5        Supermarket                 True  ...                Morning      16
# 8         Cold Store                 True  ...                 Midday       4
# 11     Hotel Kitchen                False  ...              Afternoon      17
# 14       Mini Market                False  ...                Morning      11
# 17           Grocery                False  ...              Afternoon      20
# 21          Butchery                 True  ...                Morning      38
# 25  Catering Kitchen                 True  ...                 Midday      39
# 28     Hotel Kitchen                 True  ...                Morning      45
# 31        Restaurant                 True  ...              Afternoon      10
# 34       Supermarket                 True  ...              Afternoon      88
# 36          Butchery                 True  ...                Morning       1
# 39          Butchery                 True  ...              Afternoon      38
# 42       Supermarket                 True  ...                Morning      62
# 44       Supermarket                 True  ...              Afternoon      14
# 46        Cold Store                 True  ...                Morning      39
# 49        Cold Store                 True  ...                 Midday      31
# 53          Butchery                 True  ...              Afternoon      33
# 56        Cold Store                 True  ...              Afternoon      79
# 59  Catering Kitchen                False  ...                Morning       8
# 62            Bakery                False  ...              Afternoon     142
# 64            Bakery                False  ...                 Midday       2
# 66            Bakery                False  ...              Afternoon      28
# 70       Supermarket                False  ...                 Midday      59
# 73       Mini Market                False  ...                 Midday      20
# 75       Mini Market                False  ...                 Midday      66
# 79              Cafe                False  ...                Morning      45
# 81              Cafe                False  ...                 Midday      83
# 84        Restaurant                False  ...              Afternoon       2
# 85              Cafe                False  ...                Morning       9
# 88     Hotel Kitchen                False  ...                Morning      74
# 91           Grocery                False  ...                Morning      43
# 94       Mini Market                False  ...                Morning      58
# 96           Grocery                False  ...              Afternoon      28
# 99       Supermarket                False  ...                Morning      75
#
#     frequency   monetary r_score f_score m_score rfm_score  \
# 2          37  150155.46       4       5       5       455
# 5          45   30511.53       4       5       4       454
# 8          31  146666.32       5       5       5       555
# 11         41  178871.65       4       5       5       455
# 14         10   49554.93       4       4       5       445
# 17         44  152079.19       4       5       5       455
# 21          1    8170.46       3       1       3       313
# 25          4    4411.33       3       2       2       322
# 28         22   22618.15       3       5       4       354
# 31         11   34425.62       5       4       4       544
# 34          2    6192.90       1       1       2       112
# 36          2    4243.41       5       1       2       512
# 39         24   42000.87       3       5       4       354
# 42          6    5054.57       2       3       2       232
# 44         17   40852.78       4       4       4       444
# 46          3   10491.41       3       2       3       323
# 49          6    5869.07       3       3       2       332
# 53          9   47085.08       3       3       5       335
# 56          7    7291.16       1       3       2       132
# 59         11    5835.09       5       4       2       542
# 62          1    2246.77       1       1       1       111
# 64          3    2277.69       5       2       1       521
# 66         25   40318.39       3       5       4       354
# 70          5    8896.86       2       2       3       223
# 73          4   10644.93       4       2       3       423
# 75          4    8649.37       2       2       3       223
# 79          4    8337.44       3       2       3       323
# 81          8    9791.77       1       3       3       133
# 84          3    6674.12       5       2       2       522
# 85         11   31987.73       5       4       4       544
# 88          7    2558.30       2       3       1       231
# 91         23   12487.50       3       5       3       353
# 94          6   11084.42       2       3       3       233
# 96         22   44631.47       3       5       4       354
# 99          7    7022.93       2       3       2       232
#
#                segment  assigned_sales_id
# 2             Champion        SAL_DMM_003
# 5             Champion        SAL_DMM_003
# 8             Champion        SAL_DMM_003
# 11            Champion        SAL_DMM_003
# 14            Champion        SAL_DMM_003
# 17            Champion        SAL_DMM_003
# 21      Need Attention        SAL_DMM_003
# 25      Need Attention        SAL_DMM_003
# 28               Loyal        SAL_DMM_003
# 31            Champion        SAL_DMM_003
# 34         Hibernating        SAL_DMM_003
# 36      Need Attention        SAL_DMM_003
# 39               Loyal        SAL_DMM_003
# 42             At Risk        SAL_DMM_003
# 44            Champion        SAL_DMM_003
# 46      Need Attention        SAL_DMM_003
# 49      Need Attention        SAL_DMM_003
# 53      Need Attention        SAL_DMM_003
# 56             At Risk        SAL_DMM_003
# 59      Need Attention        SAL_DMM_003
# 62         Hibernating        SAL_DMM_003
# 64  Potential Loyalist        SAL_DMM_003
# 66               Loyal        SAL_DMM_003
# 70      Need Attention        SAL_DMM_003
# 73  Potential Loyalist        SAL_DMM_003
# 75      Need Attention        SAL_DMM_003
# 79      Need Attention        SAL_DMM_003
# 81             At Risk        SAL_DMM_003
# 84  Potential Loyalist        SAL_DMM_003
# 85            Champion        SAL_DMM_003
# 88             At Risk        SAL_DMM_003
# 91               Loyal        SAL_DMM_003
# 94             At Risk        SAL_DMM_003
# 96               Loyal        SAL_DMM_003
# 99             At Risk        SAL_DMM_003
#
# [35 rows x 27 columns])})
